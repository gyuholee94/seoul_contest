# %%
# 필요한 라이브러리 임포트&설치
# !pip install dbfread
# !pip install haversine
# !pip install sklearn
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from haversine import haversine
from tqdm.notebook import tqdm
# %matplotlib inline
import platform
import pickle
import re
platform.system()
if platform.system() == 'Darwin': # Mac 환경 폰트 설정
    plt.rc('font', family='AppleGothic')
elif platform.system() == 'Windows': # Windows 환경 폰트 설정
    plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False) # 마이너스 폰트 설정
# %config InlineBackend.figure_format = 'retina'

# %%
def csv(route):
    k = pd.read_csv('{}'.format(route),encoding='cp949')
    k = k.rename(columns=k.iloc[0]).drop(k.index[0])
    return k

# %%
def pklopen(route):
    with open('./가공한데이터/{}'.format(route), 'rb') as f:
        df = pickle.load(f)
    return df
def pklsave(df, name):
    with open('{}.pkl'.format(name), 'wb') as f:
        pickle.dump(df, f)

# %%
#행정구/동 매칭
dong = pd.read_excel('./data/서울시_행정동_법정동_20200814.xlsx')
#행정동별 거주인구
dong_pop = pklopen('행정동별_거주인구_성별_연령.pickle')
#2015년 결혼상태
married_rate = pd.read_csv('./data/서울시 혼인상태별 인구(15세 이상) 통계.txt', sep='\t')
#행정동별 세대수
dong_family = pd.read_csv('./data/행정동별 세대수(17년 12월).txt', sep='\t')
#행정동별 전체인구수
total_ppl = pd.read_pickle('./data/행정동별 전체 인구.pkl')
#귀가시 어른이 맞아주시는 비율
comebackhome = pd.read_csv('./data/귀가_시__부모님_등_어른의_맞이_횟수_20201009190404.csv', encoding='cp949')

# %%
#워킹맘 보고서 2018, 워킹맘 초등학생 자녀 평균 하원, 하교시간
working_kids = {'4시이전 하원, 하교(%)':[79.6], '4시~5시 하원, 하교(%)':[14.8], '5시이후 하원, 하교(%)':[5.6]}

# %%
working_kids_df = pd.DataFrame(working_kids, index=['초등학생 비율'])
working_kids_df
# Out:
#          4시이전 하원, 하교(%)  4시~5시 하원, 하교(%)  5시이후 하원, 하교(%)
# 초등학생 비율            79.6             14.8             5.6

# %% [markdown]
# # 전처리

# %% [markdown]
# ### 틈새비율(5시 이후 하원,하교 후 집에서 아무도 맞이해주지 못하는 초등학생 비율)

# %%
comebackhome = comebackhome.rename(columns=comebackhome.iloc[0]).drop(comebackhome.index[0])
comebackhome['항상 맞이해 주시지 못한다 (%)'] = comebackhome['항상 맞이해 주시지 못한다 (%)'].astype(float)
comebackhome
# Out:
#    특성별(1)       특성별(2) 사례수 (명) 항상 맞이해 주신다 (%) 가끔 맞이해 주신다 (%)  \
# 1      전체           소계    8563           66.6           24.3
# 2      성별           남자    4318           68.3           23.2
# 3      성별           여자    4245           64.8           25.4
# 4     교급별    초등1년~초등3년    2847           71.2           19.3
# 5     교급별    초등4년~초등6년    2996           63.1           27.7
# 6     교급별    중등1년~중등3년    2720           65.4           25.8
# 7     지역별           서울    1322           71.1           20.9
# 8     지역별        인천/경기    2547           66.2           24.5
# 9     지역별  대전/충청/세종/강원    1320           63.3           26.4
# 10    지역별     광주/전라/제주    1241           61.3           27.4
# 11    지역별     부산/울산/경남    1225           66.9           25.5
# 12    지역별        대구/경북     908           72.1           20.0
# 13  지역형태별           동부    6788           66.8           24.4
# 14  지역형태별          읍면부    1775           65.5           24.1
#
#     항상 맞이해 주시지 못한다 (%)
# 1                  9.1
# 2                  8.4
# 3                  9.8
# 4                  9.4
# 5                  9.2
# 6                  8.8
# 7                  8.0
# 8                  9.2
# 9                 10.3
# 10                11.3
# 11                 7.7
# 12                 7.8
# 13                 8.8
# 14                10.4

# %%
alone_element_rate = comebackhome['항상 맞이해 주시지 못한다 (%)'].iloc[3:5].mean()
alone_element_rate
# Out:
# 9.3

# %%
working_kids_df
# Out:
#          4시이전 하원, 하교(%)  4시~5시 하원, 하교(%)  5시이후 하원, 하교(%)
# 초등학생 비율            79.6             14.8             5.6

# %%
after_five_rate = working_kids_df['5시이후 하원, 하교(%)'].iloc[0]
after_five_rate
# Out:
# 5.6

# %%
alone_after_five_rate = (alone_element_rate * after_five_rate/100).round(2)
alone_after_five_rate
# Out:
# 0.52

# %% [markdown]
# ### 동별 3040대 맞벌이 부부 & 결혼율 & 동별 0514인구 반영 돌봄필요지수

# %%
#동별 코드/구/읍면동명(행정동명)자료
dong = dong[dong['시도명']=='서울특별시']
dong_df = dong[['행정동코드','시군구명']].dropna().drop_duplicates()
dong_df['행정동코드'] = dong_df['행정동코드'].astype(str)
# dong_df.columns = ['행정동코드','시군구명','읍면동명']
dong_df
# Out:
#           행정동코드 시군구명
# 1    1111000000  종로구
# 2    1111051500  종로구
# 12   1111053000  종로구
# 24   1111054000  종로구
# 31   1111055000  종로구
# ..          ...  ...
# 763  1174065000  강동구
# 764  1174066000  강동구
# 765  1174068500  강동구
# 766  1174069000  강동구
# 767  1174070000  강동구
#
# [450 rows x 2 columns]

# %%
dong_pop
# Out:
#             ADMI_CD      ADMI_NM  5559세_2  5559세_1  5054세_1  5054세_2  4549세_1  \
# 1725910  1117051000          후암동      757      709      722      763      745
# 1725912  1159053000         상도1동     1691     1439     1535     1723     1716
# 1725913  1111070000         숭인1동      288      305      254      293      292
# 1725917  1111061500  종로1.2.3.4가동      251      549      431      164      341
# 1725919  1117057000        원효로2동      547      586      569      634      633
# ...             ...          ...      ...      ...      ...      ...      ...
# 1728432  1153059500         가리봉동      425      592      589      369      411
# 1728436  1156055000         당산1동      783      774      783      756      799
# 1728438  1141072000        북가좌2동     1486     1272     1390     1399     1383
# 1728439  1165062000         방배3동     1024      856      838      916      852
# 1728443  1156067000         신길5동      500      485      450      493      427
#
#          4549세_2  4044세_1  4044세_2  ...  2529세_1  2529세_2  2024세_1  2024세_2  \
# 1725910      782      601      653  ...      783      748      540      524
# 1725912     1678     1616     1657  ...     2631     2201     2346     2649
# 1725913      258      216      202  ...      228      225      184      179
# 1725917      218      242      157  ...      308      212      142      195
# 1725919      640      530      576  ...      501      530      385      471
# ...          ...      ...      ...  ...      ...      ...      ...      ...
# 1728432      338      284      210  ...      498      368      257      283
# 1728436      718      754      701  ...     1087     1256      552      708
# 1728438     1438     1147     1191  ...     1373     1310     1116     1110
# 1728439     1027      686      786  ...      805      720      714      688
# 1728443      428      404      400  ...      388      389      324      317
#
#          1519세_1  1519세_2  1014세_1  1014세_2  0509세_2  0509세_1
# 1725910      422      330      310      270      266      299
# 1725912      977      908      792      773      839      880
# 1725913      102      114       85       92       94       98
# 1725917       59       66       58       41       46       54
# 1725919      292      440      230      341      267      271
# ...          ...      ...      ...      ...      ...      ...
# 1728432       96       99       72       56       65       74
# 1728436      300      301      220      212      274      253
# 1728438      768      726      544      525      477      547
# 1728439      666      547      393      460      368      396
# 1728443      206      210      168      172      210      197
#
# [424 rows x 24 columns]

# %%
#동별 타겟나이 전처리
dong_pop.reset_index(inplace=True)
del dong_pop['index']
dong_pop.columns = ['행정동코드', '행정동명', '5559세_(여)', '5559세_(남)', '5054세_(남)', '5054세_(여)',
       '4549세_(남)', '4549세_(여)', '4044세_(남)', '4044세_(여)', '3539세_(남)', '3539세_(여)',
       '3034세_(남)', '3034세_(여)', '2529세_(남)', '2529세_(여)', '2024세_(남)', '2024세_(여)',
       '1519세_(남)', '1519세_(여)', '1014세_(남)', '1014세_(여)', '0509세_(여)', '0509세_(남)']
dong_pop['0514세 인구'] = dong_pop['0509세_(남)'] + dong_pop['0509세_(여)'] + dong_pop['1014세_(남)']+dong_pop['1014세_(여)']
dong_pop['30대 인구'] = dong_pop['3034세_(남)'] + dong_pop['3034세_(여)'] + dong_pop['3539세_(남)'] + dong_pop['3539세_(여)']
dong_pop['40대 인구'] = dong_pop['4044세_(남)'] + dong_pop['4044세_(여)'] + dong_pop['4549세_(남)'] + dong_pop['4549세_(여)']

dong_pop = dong_pop.replace({'행정동명': '종로5.6가동'}, {'행정동명': '종로5·6가동'})

dong_pop
# Out:
#           행정동코드         행정동명  5559세_(여)  5559세_(남)  5054세_(남)  5054세_(여)  \
# 0    1117051000          후암동        757        709        722        763
# 1    1159053000         상도1동       1691       1439       1535       1723
# 2    1111070000         숭인1동        288        305        254        293
# 3    1111061500  종로1.2.3.4가동        251        549        431        164
# 4    1117057000        원효로2동        547        586        569        634
# ..          ...          ...        ...        ...        ...        ...
# 419  1153059500         가리봉동        425        592        589        369
# 420  1156055000         당산1동        783        774        783        756
# 421  1141072000        북가좌2동       1486       1272       1390       1399
# 422  1165062000         방배3동       1024        856        838        916
# 423  1156067000         신길5동        500        485        450        493
#
#      4549세_(남)  4549세_(여)  4044세_(남)  4044세_(여)  ...  2024세_(여)  1519세_(남)  \
# 0          745        782        601        653  ...        524        422
# 1         1716       1678       1616       1657  ...       2649        977
# 2          292        258        216        202  ...        179        102
# 3          341        218        242        157  ...        195         59
# 4          633        640        530        576  ...        471        292
# ..         ...        ...        ...        ...  ...        ...        ...
# 419        411        338        284        210  ...        283         96
# 420        799        718        754        701  ...        708        300
# 421       1383       1438       1147       1191  ...       1110        768
# 422        852       1027        686        786  ...        688        666
# 423        427        428        404        400  ...        317        206
#
#      1519세_(여)  1014세_(남)  1014세_(여)  0509세_(여)  0509세_(남)  0514세 인구  30대 인구  \
# 0          330        310        270        266        299      1145    2846
# 1          908        792        773        839        880      3284    6458
# 2          114         85         92         94         98       369     845
# 3           66         58         41         46         54       199     905
# 4          440        230        341        267        271      1109    2087
# ..         ...        ...        ...        ...        ...       ...     ...
# 419         99         72         56         65         74       267    1219
# 420        301        220        212        274        253       959    4228
# 421        726        544        525        477        547      2093    4444
# 422        547        393        460        368        396      1617    3049
# 423        210        168        172        210        197       747    1603
#
#      40대 인구
# 0      2781
# 1      6667
# 2       968
# 3       958
# 4      2379
# ..      ...
# 419    1243
# 420    2972
# 421    5159
# 422    3351
# 423    1659
#
# [424 rows x 27 columns]

# %%
#동별 타겟나이 필요분만 추리기
dong_pop_need = dong_pop[['행정동코드','행정동명','0514세 인구','30대 인구','40대 인구']]
dong_pop_need['행정동코드']=dong_pop_need['행정동코드'].astype(str)
dong_pop_need['0514세 인구']=dong_pop_need['0514세 인구'].astype(int)
dong_pop_need['30대 인구']=dong_pop_need['30대 인구'].astype(int)
dong_pop_need['40대 인구']=dong_pop_need['40대 인구'].astype(int)
dong_pop_need['3040세 인구'] = dong_pop_need['30대 인구'] + dong_pop_need['40대 인구']

del dong_pop_need['30대 인구']
del dong_pop_need['40대 인구']

pop_df = pd.merge(dong_pop_need, dong_df, on='행정동코드')
pop_df
# Out:
# <ipython-input-201-89af5f5390e9>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dong_pop_need['행정동코드']=dong_pop_need['행정동코드'].astype(str)
# <ipython-input-201-89af5f5390e9>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dong_pop_need['0514세 인구']=dong_pop_need['0514세 인구'].astype(int)
# <ipython-input-201-89af5f5390e9>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dong_pop_need['30대 인구']=dong_pop_need['30대 인구'].astype(int)
# <ipython-input-201-89af5f5390e9>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dong_pop_need['40대 인구']=dong_pop_need['40대 인구'].astype(int)
# <ipython-input-201-89af5f5390e9>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dong_pop_need['3040세 인구'] = dong_pop_need['30대 인구'] + dong_pop_need['40대 인구']
#           행정동코드         행정동명  0514세 인구  3040세 인구  시군구명
# 0    1117051000          후암동      1145      5627   용산구
# 1    1159053000         상도1동      3284     13125   동작구
# 2    1111070000         숭인1동       369      1813   종로구
# 3    1111061500  종로1.2.3.4가동       199      1863   종로구
# 4    1117057000        원효로2동      1109      4466   용산구
# ..          ...          ...       ...       ...   ...
# 419  1153059500         가리봉동       267      2462   구로구
# 420  1156055000         당산1동       959      7200  영등포구
# 421  1141072000        북가좌2동      2093      9603  서대문구
# 422  1165062000         방배3동      1617      6400   서초구
# 423  1156067000         신길5동       747      3262  영등포구
#
# [424 rows x 5 columns]

# %%
#결혼율 전처리
married_rate = married_rate.rename(columns=married_rate.iloc[1]).drop(married_rate.index[:2])
married_rate_need = married_rate.iloc[:, :7]
del married_rate_need['기간']
married_rate_need.계 = married_rate_need.계.apply(lambda x: re.sub(',','', x))#.astype(int)
married_rate_need.유배우 = married_rate_need.유배우.apply(lambda x: re.sub(',','', x))#.astype(int)
married_rate_need.사별 = married_rate_need.사별.apply(lambda x: re.sub(',','', x))#.astype(int)
married_rate_need.이혼 = married_rate_need.이혼.apply(lambda x: re.sub(',','', x))#.astype(int)

married_rate_need.계 = married_rate_need.계.apply(lambda x: re.sub('-','0', x)).astype(int)
married_rate_need.유배우 = married_rate_need.유배우.apply(lambda x: re.sub('-','0', x)).astype(int)
married_rate_need.사별 = married_rate_need.사별.apply(lambda x: re.sub('-','0', x)).astype(int)
married_rate_need.이혼 = married_rate_need.이혼.apply(lambda x: re.sub('-','0', x)).astype(int)

married_rate_need
# Out:
# C:\anaconda3\lib\site-packages\pandas\core\generic.py:5165: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#      자치구     연령별        계      유배우      사별      이혼
# 2     합계      합계  8393832  4481669  519388  417869
# 3     합계   15~19   543220      305      83      17
# 4     합계   20~24   681323     6832     243     397
# 5     합계   25~29   721164    76824     200    1490
# 6     합계   30~34   821484   352439     403    7422
# ..   ...     ...      ...      ...     ...     ...
# 413  강동구   65~69    19697    15001    3021    1473
# 414  강동구   70~74    13382     9120    3359     740
# 415  강동구   75~79     8294     4568    3338     302
# 416  강동구   80~84     4802     1726    2885     147
# 417  강동구  85세 이상     3643      756    2761      61
#
# [416 rows x 6 columns]

# %%
#구별 결혼율
age30=married_rate_need['연령별'] == '30~34'
age35=married_rate_need['연령별'] == '35~39'
age40=married_rate_need['연령별'] == '40~44'
age45=married_rate_need['연령별'] == '45~49'
age_need = pd.concat([married_rate_need[age30].iloc[:,0].reset_index(), married_rate_need[age30].iloc[:,2:].reset_index() + married_rate_need[age35].iloc[:,2:].reset_index() + married_rate_need[age40].iloc[:,2:].reset_index() + married_rate_need[age45].iloc[:,2:].reset_index()], axis=1)
del age_need['index']
age_need['결혼율'] = 100*(age_need['유배우']/age_need['계']).round(4)
married_rate_gu_df = age_need[['자치구','결혼율']]
married_rate_gu_df.columns = ['시군구명','3040대 결혼율']
married_rate_gu_df
# Out:
#     시군구명  3040대 결혼율
# 0     합계      63.46
# 1    종로구      58.89
# 2     중구      55.72
# 3    용산구      59.37
# 4    성동구      62.81
# 5    광진구      59.39
# 6   동대문구      60.47
# 7    중랑구      59.82
# 8    성북구      66.26
# 9    강북구      57.55
# 10   도봉구      64.87
# 11   노원구      71.11
# 12   은평구      63.29
# 13  서대문구      61.76
# 14   마포구      61.04
# 15   양천구      71.04
# 16   강서구      65.46
# 17   구로구      65.58
# 18   금천구      57.89
# 19  영등포구      62.94
# 20   동작구      61.53
# 21   관악구      51.88
# 22   서초구      70.13
# 23   강남구      63.61
# 24   송파구      67.50
# 25   강동구      65.26

# %%
pop_df
# Out:
#           행정동코드         행정동명  0514세 인구  3040세 인구  시군구명
# 0    1117051000          후암동      1145      5627   용산구
# 1    1159053000         상도1동      3284     13125   동작구
# 2    1111070000         숭인1동       369      1813   종로구
# 3    1111061500  종로1.2.3.4가동       199      1863   종로구
# 4    1117057000        원효로2동      1109      4466   용산구
# ..          ...          ...       ...       ...   ...
# 419  1153059500         가리봉동       267      2462   구로구
# 420  1156055000         당산1동       959      7200  영등포구
# 421  1141072000        북가좌2동      2093      9603  서대문구
# 422  1165062000         방배3동      1617      6400   서초구
# 423  1156067000         신길5동       747      3262  영등포구
#
# [424 rows x 5 columns]

# %%
#동별 2인이상 가구 전체 수
dong_family_need = dong_family[['행정동','자치구','전체세대수','1인세대']]
dong_family_need['전체세대수'] = pd.to_numeric(dong_family_need['전체세대수'].apply(lambda x: re.sub(',','', x)))
dong_family_need['1인세대'] = pd.to_numeric(dong_family_need['1인세대'].apply(lambda x: re.sub(',','', x)))
dong_family_need['2인이상세대'] = dong_family_need['전체세대수']-dong_family_need['1인세대']
# dong_family_need['2인이상세대'] = dong_family_need['전체세대수']-dong_family_need['1인세대']
dong_family_df = dong_family_need[dong_family_need.행정동 !='소계']
dong_family_df = dong_family_df[dong_family_df.행정동 !='합계']
dong_family_df.columns = ['행정동명','시군구명','전체세대수','1인세대수','2인이상세대수']

total_df = pd.merge(dong_family_df, pop_df, on = ['행정동명','시군구명'])
total_df['행정동코드'] = total_df['행정동코드'].astype(str)
total_df.reset_index(inplace=True)
del total_df['index']
total_df.dropna()
# Out:
# <ipython-input-205-fbe8edb47df6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dong_family_need['전체세대수'] = pd.to_numeric(dong_family_need['전체세대수'].apply(lambda x: re.sub(',','', x)))
# <ipython-input-205-fbe8edb47df6>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dong_family_need['1인세대'] = pd.to_numeric(dong_family_need['1인세대'].apply(lambda x: re.sub(',','', x)))
# <ipython-input-205-fbe8edb47df6>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dong_family_need['2인이상세대'] = dong_family_need['전체세대수']-dong_family_need['1인세대']
#      행정동명 시군구명  전체세대수  1인세대수  2인이상세대수       행정동코드  0514세 인구  3040세 인구
# 0     사직동  종로구   4414   2061     2353  1111053000       704      2903
# 1     삼청동  종로구   1414    721      693  1111054000       165       748
# 2     부암동  종로구   4325   1623     2702  1111055000       815      2884
# 3     평창동  종로구   7510   2393     5117  1111056000      1413      5063
# 4     무악동  종로구   3024    708     2316  1111057000       925      2558
# ..    ...  ...    ...    ...      ...         ...       ...       ...
# 419  둔촌1동  강동구    888    382      506  1174069000        11        78
# 420  둔촌2동  강동구  11126   3249     7877  1174070000      2049      8081
# 421  암사1동  강동구  16345   6031    10314  1174057000      2453     11243
# 422  천호2동  강동구  17305   7991     9314  1174061000      1710     11353
# 423    길동  강동구  21066   7643    13423  1174068500      2779     14475
#
# [424 rows x 8 columns]

# %%
total_ppl.columns = ['행정동코드','행정동명','시군구명','총거주인구']
total_ppl['행정동코드'] = total_ppl['행정동코드'] + '00'
total_ppl.reset_index(inplace=True)
del total_ppl['index']

total_ppl = total_ppl.replace({'행정동명': '종로5.6가동'}, {'행정동명': '종로5·6가동'})

total_ppl[total_ppl.행정동명=='종로5·6가동']
# Out:
#           행정동코드     행정동명 시군구명  총거주인구
# 221  1111063000  종로5·6가동  종로구   5340

# %%
whole_df = pd.merge(total_df, total_ppl, on=['행정동명','시군구명','행정동코드'])
whole_df = whole_df[['행정동코드','시군구명','행정동명','0514세 인구','3040세 인구','2인이상세대수','총거주인구']]
final_df = pd.merge(whole_df, married_rate_gu_df, on='시군구명')
final_df
# Out:
#           행정동코드 시군구명  행정동명  0514세 인구  3040세 인구  2인이상세대수  총거주인구  3040대 결혼율
# 0    1111053000  종로구   사직동       704      2903     2353   9481      58.89
# 1    1111054000  종로구   삼청동       165       748      693   2718      58.89
# 2    1111055000  종로구   부암동       815      2884     2702  10093      58.89
# 3    1111056000  종로구   평창동      1413      5063     5117  18523      58.89
# 4    1111057000  종로구   무악동       925      2558     2316   8684      58.89
# ..          ...  ...   ...       ...       ...      ...    ...        ...
# 419  1174069000  강동구  둔촌1동        11        78      506    263      65.26
# 420  1174070000  강동구  둔촌2동      2049      8081     7877  27214      65.26
# 421  1174057000  강동구  암사1동      2453     11243    10314  35974      65.26
# 422  1174061000  강동구  천호2동      1710     11353     9314  34852      65.26
# 423  1174068500  강동구    길동      2779     14475    13423  46399      65.26
#
# [424 rows x 8 columns]

# %% [markdown]
# # 결혼율과 3~40대 인구 곱

# %%
final_df['3040세 기혼인구'] = ((final_df['3040세 인구'] * final_df['3040대 결혼율'])/100).round(0)
final_df
# Out:
#           행정동코드 시군구명  행정동명  0514세 인구  3040세 인구  2인이상세대수  총거주인구  3040대 결혼율  \
# 0    1111053000  종로구   사직동       704      2903     2353   9481      58.89
# 1    1111054000  종로구   삼청동       165       748      693   2718      58.89
# 2    1111055000  종로구   부암동       815      2884     2702  10093      58.89
# 3    1111056000  종로구   평창동      1413      5063     5117  18523      58.89
# 4    1111057000  종로구   무악동       925      2558     2316   8684      58.89
# ..          ...  ...   ...       ...       ...      ...    ...        ...
# 419  1174069000  강동구  둔촌1동        11        78      506    263      65.26
# 420  1174070000  강동구  둔촌2동      2049      8081     7877  27214      65.26
# 421  1174057000  강동구  암사1동      2453     11243    10314  35974      65.26
# 422  1174061000  강동구  천호2동      1710     11353     9314  34852      65.26
# 423  1174068500  강동구    길동      2779     14475    13423  46399      65.26
#
#      3040세 기혼인구
# 0        1710.0
# 1         440.0
# 2        1698.0
# 3        2982.0
# 4        1506.0
# ..          ...
# 419        51.0
# 420      5274.0
# 421      7337.0
# 422      7409.0
# 423      9446.0
#
# [424 rows x 9 columns]

# %%
final_df['3040세 세대별 기혼비율지수(기혼인구/2인이상세대수)'] = 100*(final_df['3040세 기혼인구']/final_df['2인이상세대수']).round(2)
final_df['3040세 인구별 기혼비율(기혼인구/총거주인구)'] = 100*(final_df['3040세 기혼인구']/final_df['총거주인구']).round(4)
final_df
# Out:
#           행정동코드 시군구명  행정동명  0514세 인구  3040세 인구  2인이상세대수  총거주인구  3040대 결혼율  \
# 0    1111053000  종로구   사직동       704      2903     2353   9481      58.89
# 1    1111054000  종로구   삼청동       165       748      693   2718      58.89
# 2    1111055000  종로구   부암동       815      2884     2702  10093      58.89
# 3    1111056000  종로구   평창동      1413      5063     5117  18523      58.89
# 4    1111057000  종로구   무악동       925      2558     2316   8684      58.89
# ..          ...  ...   ...       ...       ...      ...    ...        ...
# 419  1174069000  강동구  둔촌1동        11        78      506    263      65.26
# 420  1174070000  강동구  둔촌2동      2049      8081     7877  27214      65.26
# 421  1174057000  강동구  암사1동      2453     11243    10314  35974      65.26
# 422  1174061000  강동구  천호2동      1710     11353     9314  34852      65.26
# 423  1174068500  강동구    길동      2779     14475    13423  46399      65.26
#
#      3040세 기혼인구  3040세 세대별 기혼비율지수(기혼인구/2인이상세대수)  3040세 인구별 기혼비율(기혼인구/총거주인구)
# 0        1710.0                            73.0                       18.04
# 1         440.0                            63.0                       16.19
# 2        1698.0                            63.0                       16.82
# 3        2982.0                            58.0                       16.10
# 4        1506.0                            65.0                       17.34
# ..          ...                             ...                         ...
# 419        51.0                            10.0                       19.39
# 420      5274.0                            67.0                       19.38
# 421      7337.0                            71.0                       20.40
# 422      7409.0                            80.0                       21.26
# 423      9446.0                            70.0                       20.36
#
# [424 rows x 11 columns]

# %%
final_df['초등돌봄필요지수(세대별)'] = final_df['3040세 세대별 기혼비율지수(기혼인구/2인이상세대수)']*final_df['0514세 인구']
final_df['초등돌봄필요인구지수(인구별)'] = (final_df['3040세 인구별 기혼비율(기혼인구/총거주인구)']*final_df['0514세 인구']).round(0)
final_df
# Out:
#           행정동코드 시군구명  행정동명  0514세 인구  3040세 인구  2인이상세대수  총거주인구  3040대 결혼율  \
# 0    1111053000  종로구   사직동       704      2903     2353   9481      58.89
# 1    1111054000  종로구   삼청동       165       748      693   2718      58.89
# 2    1111055000  종로구   부암동       815      2884     2702  10093      58.89
# 3    1111056000  종로구   평창동      1413      5063     5117  18523      58.89
# 4    1111057000  종로구   무악동       925      2558     2316   8684      58.89
# ..          ...  ...   ...       ...       ...      ...    ...        ...
# 419  1174069000  강동구  둔촌1동        11        78      506    263      65.26
# 420  1174070000  강동구  둔촌2동      2049      8081     7877  27214      65.26
# 421  1174057000  강동구  암사1동      2453     11243    10314  35974      65.26
# 422  1174061000  강동구  천호2동      1710     11353     9314  34852      65.26
# 423  1174068500  강동구    길동      2779     14475    13423  46399      65.26
#
#      3040세 기혼인구  3040세 세대별 기혼비율지수(기혼인구/2인이상세대수)  3040세 인구별 기혼비율(기혼인구/총거주인구)  \
# 0        1710.0                            73.0                       18.04
# 1         440.0                            63.0                       16.19
# 2        1698.0                            63.0                       16.82
# 3        2982.0                            58.0                       16.10
# 4        1506.0                            65.0                       17.34
# ..          ...                             ...                         ...
# 419        51.0                            10.0                       19.39
# 420      5274.0                            67.0                       19.38
# 421      7337.0                            71.0                       20.40
# 422      7409.0                            80.0                       21.26
# 423      9446.0                            70.0                       20.36
#
#      초등돌봄필요지수(세대별)  초등돌봄필요인구지수(인구별)
# 0          51392.0          12700.0
# 1          10395.0           2671.0
# 2          51345.0          13708.0
# 3          81954.0          22749.0
# 4          60125.0          16040.0
# ..             ...              ...
# 419          110.0            213.0
# 420       137283.0          39710.0
# 421       174163.0          50041.0
# 422       136800.0          36355.0
# 423       194530.0          56580.0
#
# [424 rows x 13 columns]

# %% [markdown]
# # 틈새비율 * 초등돌봄필요지수(인구별)

# %%
final_df['틈새돌봄 필요인구지수'] = ((final_df['초등돌봄필요인구지수(인구별)'] * alone_after_five_rate)/100).round(0)
final_df
# Out:
#           행정동코드 시군구명  행정동명  0514세 인구  3040세 인구  2인이상세대수  총거주인구  3040대 결혼율  \
# 0    1111053000  종로구   사직동       704      2903     2353   9481      58.89
# 1    1111054000  종로구   삼청동       165       748      693   2718      58.89
# 2    1111055000  종로구   부암동       815      2884     2702  10093      58.89
# 3    1111056000  종로구   평창동      1413      5063     5117  18523      58.89
# 4    1111057000  종로구   무악동       925      2558     2316   8684      58.89
# ..          ...  ...   ...       ...       ...      ...    ...        ...
# 419  1174069000  강동구  둔촌1동        11        78      506    263      65.26
# 420  1174070000  강동구  둔촌2동      2049      8081     7877  27214      65.26
# 421  1174057000  강동구  암사1동      2453     11243    10314  35974      65.26
# 422  1174061000  강동구  천호2동      1710     11353     9314  34852      65.26
# 423  1174068500  강동구    길동      2779     14475    13423  46399      65.26
#
#      3040세 기혼인구  3040세 세대별 기혼비율지수(기혼인구/2인이상세대수)  3040세 인구별 기혼비율(기혼인구/총거주인구)  \
# 0        1710.0                            73.0                       18.04
# 1         440.0                            63.0                       16.19
# 2        1698.0                            63.0                       16.82
# 3        2982.0                            58.0                       16.10
# 4        1506.0                            65.0                       17.34
# ..          ...                             ...                         ...
# 419        51.0                            10.0                       19.39
# 420      5274.0                            67.0                       19.38
# 421      7337.0                            71.0                       20.40
# 422      7409.0                            80.0                       21.26
# 423      9446.0                            70.0                       20.36
#
#      초등돌봄필요지수(세대별)  초등돌봄필요인구지수(인구별)  틈새돌봄 필요인구지수
# 0          51392.0          12700.0         66.0
# 1          10395.0           2671.0         14.0
# 2          51345.0          13708.0         71.0
# 3          81954.0          22749.0        118.0
# 4          60125.0          16040.0         83.0
# ..             ...              ...          ...
# 419          110.0            213.0          1.0
# 420       137283.0          39710.0        206.0
# 421       174163.0          50041.0        260.0
# 422       136800.0          36355.0        189.0
# 423       194530.0          56580.0        294.0
#
# [424 rows x 14 columns]

# %%
final_df['틈새돌봄 필요인구지수'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
final_df['틈새돌봄 필요인구지수'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
plt.boxplot(final_df['틈새돌봄 필요인구지수'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2de5d541640>,
#   <matplotlib.lines.Line2D at 0x2de5d551fd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x2de5d551430>,
#   <matplotlib.lines.Line2D at 0x2de5d55fe20>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2de5d541c10>],
#  'medians': [<matplotlib.lines.Line2D at 0x2de5d55f2b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2de5d56fc70>],
#  'means': []}

# %%
final_df.sort_values(by='틈새돌봄 필요인구지수',ascending=False)
# Out:
#           행정동코드 시군구명     행정동명  0514세 인구  3040세 인구  2인이상세대수  총거주인구  3040대 결혼율  \
# 404  1171067000  송파구     잠실2동      6297     13331    10098  36636      67.50
# 238  1147055000  양천구      목5동      6591     13560    11969  42628      71.04
# 188  1138069000  은평구      진관동      7384     18196    14763  57622      63.29
# 118  1129066000  성북구     길음1동      5305     13021    10398  36678      66.26
# 354  1165065100  서초구     양재1동      5145     14942    12552  45147      70.13
# ..          ...  ...      ...       ...       ...      ...    ...        ...
# 10   1111067000  종로구     창신1동       174      1192     1272   5164      58.89
# 8    1111063000  종로구  종로5·6가동       146      1333     1110   5340      58.89
# 19   1114055000   중구       명동       124       841      505   2999      55.72
# 23   1114060500   중구     을지로동        44       481      247   1830      55.72
# 419  1174069000  강동구     둔촌1동        11        78      506    263      65.26
#
#      3040세 기혼인구  3040세 세대별 기혼비율지수(기혼인구/2인이상세대수)  3040세 인구별 기혼비율(기혼인구/총거주인구)  \
# 404      8998.0                            89.0                       24.56
# 238      9633.0                            80.0                       22.60
# 188     11516.0                            78.0                       19.99
# 118      8628.0                            83.0                       23.52
# 354     10479.0                            83.0                       23.21
# ..          ...                             ...                         ...
# 10        702.0                            55.0                       13.59
# 8         785.0                            71.0                       14.70
# 19        469.0                            93.0                       15.64
# 23        268.0                           109.0                       14.64
# 419        51.0                            10.0                       19.39
#
#      초등돌봄필요지수(세대별)  초등돌봄필요인구지수(인구별)  틈새돌봄 필요인구지수
# 404       560433.0         154654.0        804.0
# 238       527280.0         148957.0        775.0
# 188       575952.0         147606.0        768.0
# 118       440315.0         124774.0        649.0
# 354       427035.0         119415.0        621.0
# ..             ...              ...          ...
# 10          9570.0           2365.0         12.0
# 8          10366.0           2146.0         11.0
# 19         11532.0           1939.0         10.0
# 23          4796.0            644.0          3.0
# 419          110.0            213.0          1.0
#
# [424 rows x 14 columns]

# %% [markdown]
# # pt 하기

# %%
pt_list = np.percentile(final_df[['틈새돌봄 필요인구지수']],[i*10 for i in range(1,11)]).tolist()
pt_list
# Out:
# [53.300000000000004,
#  81.60000000000001,
#  103.89999999999999,
#  125.20000000000002,
#  150.0,
#  172.0,
#  208.09999999999997,
#  254.0,
#  347.0,
#  804.0]

# %%
qt_list = [final_df['틈새돌봄 필요인구지수'].quantile(0.25),final_df['틈새돌봄 필요인구지수'].quantile(0.5),final_df['틈새돌봄 필요인구지수'].quantile(0.75),final_df['틈새돌봄 필요인구지수'].quantile(1)]
qt_list
# Out:
# [90.75, 150.0, 228.5, 804.0]

# %%
# 초등돌봄틈새필요분위 컬럼
final_df['초등돌봄틈새필요분위'] = 0
final_df.loc[final_df['틈새돌봄 필요인구지수'] <= pt_list[0], '초등돌봄틈새필요분위'] = 1
final_df.loc[(final_df['틈새돌봄 필요인구지수'] > pt_list[0]) & (final_df['틈새돌봄 필요인구지수'] <= pt_list[1]),'초등돌봄틈새필요분위'] = 2
final_df.loc[(final_df['틈새돌봄 필요인구지수'] > pt_list[1]) & (final_df['틈새돌봄 필요인구지수'] <= pt_list[2]),'초등돌봄틈새필요분위'] = 3
final_df.loc[(final_df['틈새돌봄 필요인구지수'] > pt_list[2]) & (final_df['틈새돌봄 필요인구지수'] <= pt_list[3]),'초등돌봄틈새필요분위'] = 4
final_df.loc[(final_df['틈새돌봄 필요인구지수'] > pt_list[3]) & (final_df['틈새돌봄 필요인구지수'] <= pt_list[4]),'초등돌봄틈새필요분위'] = 5
final_df.loc[(final_df['틈새돌봄 필요인구지수'] > pt_list[4]) & (final_df['틈새돌봄 필요인구지수'] <= pt_list[5]),'초등돌봄틈새필요분위'] = 6
final_df.loc[(final_df['틈새돌봄 필요인구지수'] > pt_list[5]) & (final_df['틈새돌봄 필요인구지수'] <= pt_list[6]),'초등돌봄틈새필요분위'] = 7
final_df.loc[(final_df['틈새돌봄 필요인구지수'] > pt_list[6]) & (final_df['틈새돌봄 필요인구지수'] <= pt_list[7]),'초등돌봄틈새필요분위'] = 8
final_df.loc[(final_df['틈새돌봄 필요인구지수'] > pt_list[7]) & (final_df['틈새돌봄 필요인구지수'] <= pt_list[8]),'초등돌봄틈새필요분위'] = 9
final_df.loc[(final_df['틈새돌봄 필요인구지수'] > pt_list[8]) & (final_df['틈새돌봄 필요인구지수'] <= pt_list[9]),'초등돌봄틈새필요분위'] = 10

final_df
# Out:
#           행정동코드 시군구명  행정동명  0514세 인구  3040세 인구  2인이상세대수  총거주인구  3040대 결혼율  \
# 0    1111053000  종로구   사직동       704      2903     2353   9481      58.89
# 1    1111054000  종로구   삼청동       165       748      693   2718      58.89
# 2    1111055000  종로구   부암동       815      2884     2702  10093      58.89
# 3    1111056000  종로구   평창동      1413      5063     5117  18523      58.89
# 4    1111057000  종로구   무악동       925      2558     2316   8684      58.89
# ..          ...  ...   ...       ...       ...      ...    ...        ...
# 419  1174069000  강동구  둔촌1동        11        78      506    263      65.26
# 420  1174070000  강동구  둔촌2동      2049      8081     7877  27214      65.26
# 421  1174057000  강동구  암사1동      2453     11243    10314  35974      65.26
# 422  1174061000  강동구  천호2동      1710     11353     9314  34852      65.26
# 423  1174068500  강동구    길동      2779     14475    13423  46399      65.26
#
#      3040세 기혼인구  3040세 세대별 기혼비율지수(기혼인구/2인이상세대수)  3040세 인구별 기혼비율(기혼인구/총거주인구)  \
# 0        1710.0                            73.0                       18.04
# 1         440.0                            63.0                       16.19
# 2        1698.0                            63.0                       16.82
# 3        2982.0                            58.0                       16.10
# 4        1506.0                            65.0                       17.34
# ..          ...                             ...                         ...
# 419        51.0                            10.0                       19.39
# 420      5274.0                            67.0                       19.38
# 421      7337.0                            71.0                       20.40
# 422      7409.0                            80.0                       21.26
# 423      9446.0                            70.0                       20.36
#
#      초등돌봄필요지수(세대별)  초등돌봄필요인구지수(인구별)  틈새돌봄 필요인구지수  초등돌봄틈새필요분위
# 0          51392.0          12700.0         66.0           2
# 1          10395.0           2671.0         14.0           1
# 2          51345.0          13708.0         71.0           2
# 3          81954.0          22749.0        118.0           4
# 4          60125.0          16040.0         83.0           3
# ..             ...              ...          ...         ...
# 419          110.0            213.0          1.0           1
# 420       137283.0          39710.0        206.0           7
# 421       174163.0          50041.0        260.0           9
# 422       136800.0          36355.0        189.0           7
# 423       194530.0          56580.0        294.0           9
#
# [424 rows x 15 columns]

# %%
# 초등돌봄필요사분위 컬럼
final_df['초등돌봄틈새필요사분위'] = 0
final_df.loc[final_df['틈새돌봄 필요인구지수'] <= qt_list[0], '초등돌봄틈새필요사분위'] = 0.25
final_df.loc[(final_df['틈새돌봄 필요인구지수'] > qt_list[0]) & (final_df['틈새돌봄 필요인구지수'] <= qt_list[1]),'초등돌봄틈새필요사분위'] = 0.5
final_df.loc[(final_df['틈새돌봄 필요인구지수'] > qt_list[1]) & (final_df['틈새돌봄 필요인구지수'] <= qt_list[2]),'초등돌봄틈새필요사분위'] = 0.75
final_df.loc[(final_df['틈새돌봄 필요인구지수'] > qt_list[2]) & (final_df['틈새돌봄 필요인구지수'] <= qt_list[3]),'초등돌봄틈새필요사분위'] = 1

final_df
# Out:
#           행정동코드 시군구명  행정동명  0514세 인구  3040세 인구  2인이상세대수  총거주인구  3040대 결혼율  \
# 0    1111053000  종로구   사직동       704      2903     2353   9481      58.89
# 1    1111054000  종로구   삼청동       165       748      693   2718      58.89
# 2    1111055000  종로구   부암동       815      2884     2702  10093      58.89
# 3    1111056000  종로구   평창동      1413      5063     5117  18523      58.89
# 4    1111057000  종로구   무악동       925      2558     2316   8684      58.89
# ..          ...  ...   ...       ...       ...      ...    ...        ...
# 419  1174069000  강동구  둔촌1동        11        78      506    263      65.26
# 420  1174070000  강동구  둔촌2동      2049      8081     7877  27214      65.26
# 421  1174057000  강동구  암사1동      2453     11243    10314  35974      65.26
# 422  1174061000  강동구  천호2동      1710     11353     9314  34852      65.26
# 423  1174068500  강동구    길동      2779     14475    13423  46399      65.26
#
#      3040세 기혼인구  3040세 세대별 기혼비율지수(기혼인구/2인이상세대수)  3040세 인구별 기혼비율(기혼인구/총거주인구)  \
# 0        1710.0                            73.0                       18.04
# 1         440.0                            63.0                       16.19
# 2        1698.0                            63.0                       16.82
# 3        2982.0                            58.0                       16.10
# 4        1506.0                            65.0                       17.34
# ..          ...                             ...                         ...
# 419        51.0                            10.0                       19.39
# 420      5274.0                            67.0                       19.38
# 421      7337.0                            71.0                       20.40
# 422      7409.0                            80.0                       21.26
# 423      9446.0                            70.0                       20.36
#
#      초등돌봄필요지수(세대별)  초등돌봄필요인구지수(인구별)  틈새돌봄 필요인구지수  초등돌봄틈새필요분위  초등돌봄틈새필요사분위
# 0          51392.0          12700.0         66.0           2         0.25
# 1          10395.0           2671.0         14.0           1         0.25
# 2          51345.0          13708.0         71.0           2         0.25
# 3          81954.0          22749.0        118.0           4         0.50
# 4          60125.0          16040.0         83.0           3         0.25
# ..             ...              ...          ...         ...          ...
# 419          110.0            213.0          1.0           1         0.25
# 420       137283.0          39710.0        206.0           7         0.75
# 421       174163.0          50041.0        260.0           9         1.00
# 422       136800.0          36355.0        189.0           7         0.75
# 423       194530.0          56580.0        294.0           9         1.00
#
# [424 rows x 16 columns]

# %%
alone_need_df = final_df[['행정동코드','시군구명','행정동명','틈새돌봄 필요인구지수','초등돌봄틈새필요분위','초등돌봄틈새필요사분위']]
alone_need_df.columns = [['행정동코드','시군구명','행정동명','틈새돌봄필요 지수','틈새돌봄 필요분위','틈새돌봄 필요사분위']]
alone_need_df
# Out:
#           행정동코드 시군구명  행정동명 틈새돌봄필요 지수 틈새돌봄 필요분위 틈새돌봄 필요사분위
# 0    1111053000  종로구   사직동      66.0         2       0.25
# 1    1111054000  종로구   삼청동      14.0         1       0.25
# 2    1111055000  종로구   부암동      71.0         2       0.25
# 3    1111056000  종로구   평창동     118.0         4       0.50
# 4    1111057000  종로구   무악동      83.0         3       0.25
# ..          ...  ...   ...       ...       ...        ...
# 419  1174069000  강동구  둔촌1동       1.0         1       0.25
# 420  1174070000  강동구  둔촌2동     206.0         7       0.75
# 421  1174057000  강동구  암사1동     260.0         9       1.00
# 422  1174061000  강동구  천호2동     189.0         7       0.75
# 423  1174068500  강동구    길동     294.0         9       1.00
#
# [424 rows x 6 columns]

# %%
alone_need_df.to_pickle('틈새돌봄필요지수.pkl')
alone_need_df.to_csv('틈새돌봄필요지수.csv')

# %%
pd.read_pickle('./data/양천구_초등학생880m_인구.pickle')
# Out:
#             gid       행정동코드    행정동                             학교명  학교개수  \
# 0    다사40aa48ba  1147058000   신월3동                      [서울양원초등학교]     1
# 1    다사40aa48bb  1147058000   신월3동                      [서울양원초등학교]     1
# 2    다사40aa49aa  1147058000   신월3동            [서울강신초등학교, 서울양원초등학교]     2
# 3    다사40aa49ab  1150061100  발산제1동            [서울강신초등학교, 서울양원초등학교]     2
# 4    다사40ab45bb  1147064000   신정3동                      [서울신은초등학교]     1
# ..          ...         ...    ...                             ...   ...
# 326  다사45bb48bb  1147055000    목5동  [서울선유초등학교, 서울목원초등학교, 서울경인초등학교]     3
# 327  다사45bb49aa  1147055000    목5동  [서울당산초등학교, 서울목원초등학교, 서울경인초등학교]     3
# 328  다사46aa48aa  1147055000    목5동  [서울선유초등학교, 서울당중초등학교, 서울경인초등학교]     3
# 329  다사46aa48ab  1147055000    목5동  [서울선유초등학교, 서울당중초등학교, 서울경인초등학교]     3
# 330  다사46aa48ba  1147055000    목5동  [서울선유초등학교, 서울당산초등학교, 서울경인초등학교]     3
#
#      초등학생_인구  30대_인구  40대_인구          경도         위도  \
# 0        8.0    30.0    21.0  126.822293  37.534999
# 1        0.0     0.0     0.0  126.822272  37.537253
# 2        0.0     0.0     0.0  126.822252  37.539506
# 3        0.0     0.0     0.0  126.822231  37.541759
# 4        0.0     0.0     0.0  126.825345  37.510230
# ..       ...     ...     ...         ...        ...
# 326      0.0     0.0     0.0  126.887353  37.537608
# 327      0.0     0.0     0.0  126.887335  37.539861
# 328      0.0     0.0     0.0  126.890238  37.530863
# 329      0.0     0.0     0.0  126.890219  37.533116
# 330      0.0     0.0     0.0  126.890201  37.535370
#
#                        geometry
# 0    POINT (126.82229 37.53500)
# 1    POINT (126.82227 37.53725)
# 2    POINT (126.82225 37.53951)
# 3    POINT (126.82223 37.54176)
# 4    POINT (126.82535 37.51023)
# ..                          ...
# 326  POINT (126.88735 37.53761)
# 327  POINT (126.88733 37.53986)
# 328  POINT (126.89024 37.53086)
# 329  POINT (126.89022 37.53312)
# 330  POINT (126.89020 37.53537)
#
# [331 rows x 11 columns]
