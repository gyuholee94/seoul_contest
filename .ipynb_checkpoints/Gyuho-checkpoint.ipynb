# %% [markdown]
# # 복지시설 데이터 동별 매칭

# %% [markdown]
# ⇒ 돌봄시설 API
#
# 규호: 공원, 도서관, 체육시설, 대중교통
#
# 하은: 경찰범죄통계, 5대 범죄 구별 범죄율, 주차, 57번
#
# 재영: 초/ 중/고등/대학교, 도로, (각 초등학교가 커버하는 범위?), 56번, 31번
#
# 동명: 상권, 학원가, 공장, 병원, 69번, 58번
#
# 소연: 건폐율, 전용면적, 각 행정동 안에 주택개수(코드)
#
# ⇒ 행정동별로 개수, 평균
#
# ⇒ X, Y 좌표 (위도, 경도)
#
# ⇒ 동별로 없으면? 구별로도
#
# ⇒ 개수, 면적(규모)

# %%
# 필요한 라이브러리 임포트&설치
# !pip install dbfread
# !pip install haversine
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from haversine import haversine
from tqdm.notebook import tqdm
# %matplotlib inline
import platform
import pickle
import re
platform.system()
if platform.system() == 'Darwin': # Mac 환경 폰트 설정
    plt.rc('font', family='AppleGothic')
elif platform.system() == 'Windows': # Windows 환경 폰트 설정
    plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False) # 마이너스 폰트 설정
# %config InlineBackend.figure_format = 'retina'
# Out:
# Requirement already satisfied: dbfread in c:\anaconda3\lib\site-packages (2.0.7)
# Requirement already satisfied: haversine in c:\anaconda3\lib\site-packages (2.3.0)

# %% [markdown]
# 서울시 전체에 분포한
#
# 공원, 도서관, 대중교통(지하철/버스), 체육시설, +미술관박물관
#
# 을 동별로 몇개씩 있는지 분배한 데이터프레임을 만들면 되는데,
#
# 동별이 안되면 구별로 하면 됨.
#
# 위도경도 따져주고
#
# 가능하면 부가정보도(넓이라던가 수용인원이라던가 연식이라던가)
#
# 1. 일단 주소/위도경도만 남기고 다 없애자(흔적은 columns해서 남길것)
#
# 2. re findall로 동만 추출한다거나, 구 추출해서 매칭해주기(새로운 열)
#
# 3. 데이터 적은거로 구별 중심으로 해서 가까운곳 매칭하는것(지하철/버스) 해서 옆에 ~동 이렇게 하던지 동옆에 ~개 이렇게 하던지.

# %%
###필요한 데이터 불러오기
#대중교통-버스정류소
bus = pd.read_excel(r'C:\Users\이규호\NLP\github\seoul_contest\data\서울시버스정류소좌표데이터(2020.03.06).xlsx', encoding='cp949')
#공원
park = pd.read_csv(r'C:\Users\이규호\NLP\github\seoul_contest\data\서울시 주요 공원현황.csv', encoding='cp949')
#박물관
museum = pd.read_csv(r'C:\Users\이규호\NLP\github\seoul_contest\data\서울특별시_박물관미술관정보_20180821.csv', encoding='cp949')
#도서관
lib = pd.read_csv(r'C:\Users\이규호\NLP\github\seoul_contest\data\전국도서관표준데이터.csv', encoding='cp949')

###없는데이터 목록
#체육시설-하은이 기다려야함
# sports = pd.read_csv()
#대중교통-지하철-못찾았었음(그나마1-4호선)

###위치매핑등을 위해 동별 구분단위 불러오기
#동사무소
office = pd.read_csv(r'C:\Users\이규호\NLP\github\seoul_contest\data\전국공공시설개방정보표준데이터.csv', encoding='cp949')
#구 좌표
gu_loc = pd.read_csv(r'C:\Users\이규호\NLP\github\seoul_contest\data\서울시 행정구역 시군구 정보 (좌표계_ WGS1984).csv', encoding='cp949')
#행정동목록
dong = pd.read_excel(r'C:\Users\이규호\NLP\github\seoul_contest\data\서울시_행정동_법정동_20200814.xlsx', encoding='cp949')

# %% [markdown]
# 출처:
#
# 버스:https://data.seoul.go.kr/dataList/OA-15067/S/1/datasetView.do
#
# 공원: http://data.seoul.go.kr/dataList/OA-394/S/1/datasetView.do;jsessionid=C03761A8C8B90B16BD4AD7EAD8E06367.new_portal-svr-21
#
# 미술/박물관:http://data.seoul.go.kr/dataList/OA-15272/F/1/datasetView.do
#
# 도서관:https://www.data.go.kr/data/15013109/standard.do
#
# 지하철:http://data.seoul.go.kr/dataList/OA-12035/A/1/datasetView.do;jsessionid=E738D56520A14676B34670384E77126E.new_portal-svr-11
#
# 동사무소:https://www.data.go.kr/data/15013117/standard.do
#
# 구좌표:https://data.seoul.go.kr/dataList/OA-11677/S/1/datasetView.do
#
# 행정동목록: 소연이

# %% [markdown]
# # 원본 데이터 오픈

# %%
bus
# Out:
#             표준ID  ARS-ID           정류장명         X좌표        Y좌표   비고
# 0      100000001    1001        종로2가사거리  126.987750  37.569765  NaN
# 1      100000002    1002    창경궁.서울대학교병원  126.996566  37.579183  NaN
# 2      100000003    1003      명륜3가.성대입구  126.998340  37.582671  NaN
# 3      100000004    1004       종로2가.삼일교  126.987613  37.568579  NaN
# 4      100000005    1005  혜화동로터리.여운형활동터  127.001744  37.586243  NaN
# ...          ...     ...            ...         ...        ...  ...
# 11275  124000334   25995          우성아파트  127.139339  37.550386  NaN
# 11276  124000333   25996          우성아파트  127.140046  37.550643  NaN
# 11277  124000332   25997           조일약국  127.123596  37.533630  NaN
# 11278  124000331   25998           성내시장  127.125497  37.536155  NaN
# 11279  124000330   25999    천호우체국.로데오거리  127.127337  37.540343  NaN
#
# [11280 rows x 6 columns]

# %%
park
# Out:
#      공원번호              공원명                                               공원개요  \
# 0       1         남산도시자연공원  남산공원은 도심에 위치하여 서울시민에게 맑은 공기를 제공하는 자연휴식처이며 산책 꽃...
# 1       3           길동생태공원  길동생태공원은 생물의 서식처를 제공하고 종다양성을 증진시키며 자연생태계의 생물들을 ...
# 2       4            서울대공원  서울대공원은 세계 각국의 야생동물들이 살아 숨 쉬는 서울동물원과 다양한 재미와 즐거...
# 3       5              서울숲  당초 골프장 승마장 등이 있던 뚝섬일대를 주거업무 지역으로 개발할 경우 약 4조원에...
# 4       6            월드컵공원  월드컵공원은 서울의 서쪽에 위치하여 1978년부터 1993년까지 15년간 서울시민이...
# ..    ...              ...                                                ...
# 127  1378  용마도시자연공원(사가정공원)  2005년 4월 13일 개장한 사가정공원은 면목동 산 50번지 일대의 면목약수터지구...
# 128  1379           문화비축기지  매봉산자락에 위치한 문화비축기지는 폐산업시설인 '마포석유비축기지'를 재생하여 역사적...
# 129  1380            경춘선숲길  일제 강점기때 우리 민족의 자본으로 만든 최초의 철도시설로 1939년 7월 25일 ...
# 130  1381             율현공원  ? 율현공원은 보금자리주택 세곡2지구 사업의 결과물로 만들어졌다. 공원은 주택지구의...
# 131  1382          서울로7017  서울로7017은 70년대 준공된 서울역 고가가 안전에 문제점이 도출되면서 철거가 될...
#
#                                                면적         개원일  \
# 0    2896887㎡ 임 야 : 2454140㎡ 녹지대 및 기타시설 : 442747㎡   1968.9.10
# 1                                          80683㎡   1999.5.20
# 2                                       9132690m²    1984.5.1
# 3                                         480994㎡   2005.6.18
# 4                                        2284085㎡    2002.5.1
# ..                                            ...         ...
# 127                                      109635㎡   2005.4.13
# 128                                       140022㎡    2017.9.1
# 129                                       211392㎡         NaN
# 130                                       157535㎡   2016.11.1
# 131                                           NaN         NaN
#
#                                                   주요시설  \
# 0    기반시설 : 광장 45950㎡ 도로 108530㎡ 산책로 6.7㎞ (북측:3.7㎞/...
# 1                 탐방객안내소 야외전시대 관찰대 목재데크 조류관찰대 길동생태문화센터
# 2    동물원 식물원 테마가든(장미원 어린이동물원 피크닉장) 치유숲 산림욕장 캠핑장 국립현...
# 3    4개 테마공원: 문화예술공원 자연생태숲 자연체험학습원 습지생태원 주요시설: 가족마당...
# 4    평화의 공원 월드컵공원전시관(879㎡) 유니세프광장(2400㎡) 평화광장(5217㎡...
# ..                                                 ...
# 127                               피크닉장 놀이터 체력단련장 체육관
# 128                                     6개의탱크와 문화마당 녹지
# 129  조경시설 : 텃밭 잔디광장 철길 산책로 등 건축시설 : 무궁화호 객차(방문자센터) ...
# 130  관리시설 : 사무실 조경시설 : 정자(4개) 조형쉼터(10개) 조형파고라(3개) 수...
# 131                                                NaN
#
#                                                   주요식물  \
# 0                    소나무 단풍 아카시아 상수리나무 등 191종 2881870주
# 1            소나무 보리수 등 64종 31800주 산국 부들 등 138종 192800본
# 2                                                  NaN
# 3    수 목 : 소나무 섬잣나무 계수나무 외 95종 415795주 식물원 : 선인장 등 ...
# 4                                                  NaN
# ..                                                 ...
# 127                                                NaN
# 128                                                NaN
# 129                                                NaN
# 130  수목 : 소나무 이팝나무 등  110종  143069주 초화 : 맥문동 벌개미취 등...
# 131                                                NaN
#
#                                                    안내도  \
# 0    http://parks.seoul.go.kr/upload/seditorMulti/2...
# 1    http://parks.seoul.go.kr/template/common/img/p...
# 2                                                  NaN
# 3    http://parks.seoul.go.kr/template/common/img/p...
# 4    http://parks.seoul.go.kr/template/common/img/p...
# ..                                                 ...
# 127                                                NaN
# 128  http://parks.seoul.go.kr/upload/seditorMulti/2...
# 129                                                NaN
# 130  http://parks.seoul.go.kr/upload/seditorMulti/2...
# 131                                                NaN
#
#                                                   오시는길  \
# 0    명동역(남산케이블카 와룡묘 서울애니메이션센터 방면) 도보 명동역 3번출구 → 퍼시픽...
# 1                                                  NaN
# 2    지하철 4호선 대공원역 하차(2번 출구) 도보 15분 정도 문의처 02)500-73...
# 3                                                  NaN
# 4    지하철 6호선 월드컵경기장역 하차 → 1번 출구로 나온 후 직진 → 큰길(도로)이 ...
# ..                                                 ...
# 127                                                NaN
# 128                                                NaN
# 129  지하철 이용시 지하철 7호선 하계역 4번출구 미성/장미아파트 도로 450m직진 지하...
# 130                                                NaN
# 131  중림 만리동(서울로 종점부에서 진입) 지하철- 충정로(경기대입구) - 2 5호선 :...
#
#                                                이용시참고사항  \
# 0    남산공원 차량통행 금지안내 2005년 5월 1일부터 남산공원에 일반승용차 택시 통행...
# 1    매주 월요일은 휴관입니다 사전예약 후 입장하실 수 있습니다. ▶ 인터넷 예약 바로가...
# 2    일반사항 공원을 깨끗하게 이용합니다. 대중교통을 이용해 주세요. 기념물 시설물 풀과...
# 3    지하철 분당선 서울숲역 3번출구 도보로 약5분 2호선 뚝섬역 8번출구 도보로 약 1...
# 4    일반사항 공원을 깨끗하게 이용합니다. 대중교통을 이용해 주세요. 기념물 시설물 풀과...
# ..                                                 ...
# 127                                                NaN
# 128   ? 일반사항  - 공원은 연중무휴이나 전시관은 월요일 휴관입니다.   - 공원을 ...
# 129  ○ 6.3km   (시 작 점 : 육사삼거리   중간지점 : 화랑대사거리 → 화랑대...
# 130  공원 인근에 서울공항 활주로가 위치하고 있어 공원 내에서 드론을 날리거나 헬륨가스 ...
# 131                                                NaN
#
#                                                    이미지   지역  \
# 0    http://parks.seoul.go.kr/file/info/view.do?fId...   중구
# 1    http://parks.seoul.go.kr/file/info/view.do?fId...  강동구
# 2    http://parks.seoul.go.kr/file/info/view.do?fId...  과천시
# 3    http://parks.seoul.go.kr/file/info/view.do?fId...  성동구
# 4    http://parks.seoul.go.kr/file/info/view.do?fId...  마포구
# ..                                                 ...  ...
# 127  http://parks.seoul.go.kr/file/info/view.do?fId...  중랑구
# 128  http://parks.seoul.go.kr/file/info/view.do?fId...  마포구
# 129  http://parks.seoul.go.kr/file/info/view.do?fId...  NaN
# 130  http://parks.seoul.go.kr/file/info/view.do?fId...  강남구
# 131  http://parks.seoul.go.kr/file/info/view.do?fId...   중구
#
#                               공원주소              관리부서          전화번호  \
# 0           서울특별시 중구 삼일대로 231(예장동)    서울특별시중부푸른도시사업소  02-3783-5900
# 1     서울특별시 강동구 천호대로 1291(길동생태공원)   동부공원녹지사업소 길동생태공원   02-489-2770
# 2               경기도 과천시 대공원광장로 102             전략기획실   02-500-7032
# 3       서울특별시 성동구 뚝섬로 273 (성수동1가)          서울숲 관리사무소  02-460-2905
# 4        서울특별시 마포구 하늘공원로 84(월드컵공원)             월드컵공원   02-300-5500
# ..                             ...               ...           ...
# 127            서울특별시 중랑구 면목7동 산50         중랑구청 공원녹지과  02-2094-2993
# 128               서울특별시 마포구 증산로 87            문화비축기지   02-376-8410
# 129                노원구 공릉2동 산 82-2         중부공원녹지사업소  02-2289-4012
# 130  서울특별시 강남구 율현동 밤고개로24길(율현동 56)         동부공원녹지사업소   02-459-9452
# 131                        서울로7017            서울로운영단   02-313-7017
#
#       X좌표(GRS80TM)  Y좌표(GRS80TM)  X좌표(WGS84)  Y좌표(WGS84)  \
# 0    198364.107000  4.503956e+05  126.990377   37.550140
# 1    213554.120000  4.488527e+05  127.154779   37.540394
# 2    200994.267000  4.371640e+05  127.019847   37.426449
# 3    203695.432000  4.492907e+05  127.041798   37.543072
# 4    190658.070000  4.515988e+05  126.878907   37.571805
# ..             ...           ...         ...         ...
# 127            NaN           NaN  127.095997   37.579762
# 128  114264.460400  3.712093e+06  126.893245   37.571718
# 129     127.076482  3.762708e+01  127.076482   37.627077
# 130            NaN           NaN  127.115594   37.472332
# 131            NaN           NaN         NaN         NaN
#
#                                                   바로가기
# 0      http://parks.seoul.go.kr/template/sub/namsan.do
# 1     http://parks.seoul.go.kr/template/sub/gildong.do
# 2                        http://grandpark.seoul.go.kr/
# 3    http://parks.seoul.go.kr/template/sub/seoulfor...
# 4    http://parks.seoul.go.kr/template/sub/worldcup...
# ..                                                 ...
# 127                                                NaN
# 128  http://parks.seoul.go.kr/template/sub/culturet...
# 129                                                NaN
# 130                                                NaN
# 131                                                NaN
#
# [132 rows x 20 columns]

# %%
museum
# Out:
#            시설명 박물관미술관구분                         소재지도로명주소  소재지지번주소         위도  \
# 0        둘리뮤지엄       공립              서울특별시 도봉구 시루봉로 1길 6      NaN  37.652432
# 1    서대문자연사박물관       공립            서울특별시 서대문구 연희로 32길 51      NaN  37.576753
# 2    서대문형무소역사관       공립                서울특별시 서대문구 통일로251      NaN  37.572442
# 3      서울교육박물관       공립              서울특별시 종로구 북촌로 5길 48      NaN  37.581031
# 4       서울상상나라       공립                서울특별시 광진구 능동로 216      NaN  37.549458
# ..         ...      ...                              ...      ...        ...
# 154     포스코미술관       사립       서울특별시 강남구 대치4동 892 포스코센터 내      NaN  37.505831
# 155     학아재미술관       사립                서울특별시 종로구 돈화문로 98      NaN        NaN
# 156    한미사진미술관       사립  서울특별시 송파구 위례성대로 14 한미타워 19, 20층      NaN  37.516608
# 157    헬로우뮤지움      사립                   서울특별시 성동구 금호로 72      NaN  37.507358
# 158     환기미술관        사립            서울특별시 종로구 자하문로 40길 63      NaN  37.594431
#
#              경도      운영기관전화번호        운영기관명                          운영홈페이지  \
# 0    127.027640   02-990-2200          도봉구               doolymuseum.or.kr
# 1    126.937858   02-330-8899         서대문구           http://namu.sdm.go.kr
# 2    126.959541   02-360-8590         서대문구                 www.sscmc.or.kr
# 3    126.983694  02-2011-5780  서울특별시특별시교육청      http://edumuseum.sen.go.kr
# 4    127.086261  02-6450-9500     서울특별시특별시    www.seoulchildrensmuseum.org
# ..          ...           ...          ...                             ...
# 154  127.056088  02-3457-1665         ㈜포스코  http://www.poscoartmuseum.org/
# 155         NaN   02-766-7647          김로이                 www.hagajae.com
# 156  127.113970   02-418-1315       가현문화재단           www.photomuseum.or.kr
# 157  127.040312  02-3217-4222   김효정\n(김이삭)             www.hellomuseum.com
# 158  126.966289   02-391-7701     (재)환기재단         http://whankimuseum.org/
#
#      편의시설정보  ...    휴관정보 어른관람료 청소년관람료 어린이관람료 관람료기타정보 박물관미술관소개 교통안내정보  \
# 0       NaN  ...  홈페이지참고  5000   5000   5000     NaN      NaN    NaN
# 1       NaN  ...  홈페이지참고  6000   3000   2000     NaN      NaN    NaN
# 2       NaN  ...  홈페이지참고  3000   1500   1000     NaN      NaN    NaN
# 3       NaN  ...  홈페이지참고     0      0      0     NaN      NaN    NaN
# 4       NaN  ...  홈페이지참고  4000   4000   4000     NaN      NaN    NaN
# ..      ...  ...     ...   ...    ...    ...     ...      ...    ...
# 154     NaN  ...  홈페이지참고   NaN    NaN    NaN     NaN      NaN    NaN
# 155     NaN  ...  홈페이지참고   NaN    NaN    NaN     NaN      NaN    NaN
# 156     NaN  ...  홈페이지참고   NaN    NaN    NaN     NaN      NaN    NaN
# 157     NaN  ...  홈페이지참고   NaN    NaN    NaN     NaN      NaN    NaN
# 158     NaN  ...  홈페이지참고   NaN    NaN    NaN     NaN      NaN    NaN
#
#          관리기관전화번호        관리기관명     데이터기준일자
# 0     02-990-2200          도봉구  2017-12-31
# 1     02-330-8899         서대문구  2017-12-31
# 2     02-360-8590         서대문구  2017-12-31
# 3    02-2011-5780  서울특별시특별시교육청  2017-12-31
# 4    02-6450-9500     서울특별시특별시  2017-12-31
# ..            ...          ...         ...
# 154  02-3457-1665         ㈜포스코  2017-12-31
# 155   02-766-7647          김로이  2017-12-31
# 156   02-418-1315       가현문화재단  2017-12-31
# 157  02-3217-4222   김효정\n(김이삭)  2017-12-31
# 158   02-391-7701     (재)환기재단   2017-12-31
#
# [159 rows x 24 columns]

# %%
lib
# Out:
#                    도서관명   시도명 시군구명  도서관유형  \
# 0     덕산아내프리미엄아파트 작은도서관  경상남도  거제시  작은도서관
# 1               강하작은도서관   경기도  양평군  작은도서관
# 2               강상작은도서관   경기도  양평군  작은도서관
# 3                 양동도서관   경기도  양평군  공공도서관
# 4                 지평도서관   경기도  양평군  공공도서관
# ...                 ...   ...  ...    ...
# 3313        늘푸른 도서관 하동군  경상남도  하동군  작은도서관
# 3314          밀양시립영어도서관  경상남도  밀양시  공공도서관
# 3315            밀양시립도서관  경상남도  밀양시  공공도서관
# 3316            나주시립도서관  전라남도  나주시  공공도서관
# 3317           빛가람시립도서관  전라남도  나주시  공공도서관
#
#                                         휴관일 평일운영시작시각 평일운영종료시각 토요일운영시작시각  \
# 0                                매주월요일, 공휴일    16:00    22:00     16:00
# 1                                 매주일,월/공휴일    09:00    18:00     09:00
# 2                                 매주일,월/공휴일    09:00    18:00     09:00
# 3                                 신정,설,추석연휴    08:00    22:00     08:00
# 4                                 신정,설,추석연휴    08:00    22:00     08:00
# ...                                     ...      ...      ...       ...
# 3313                                  매주월요일    11:00    17:00     13:00
# 3314  매주 월요일, 신정, 구정, 추석 연휴일, 기타 도서관장이 정한 날    09:00    18:00     09:00
# 3315  매주 월요일, 신정, 구정, 추석 연휴일, 기타 도서관장이 정한 날    08:00    23:00     08:00
# 3316                   매월 첫째, 셋째 월요일, 법정공휴일    08:00    23:00     08:00
# 3317                   매월 첫째, 셋째 월요일, 법정공휴일    08:00    23:00     08:00
#
#      토요일운영종료시각 공휴일운영시작시각  ...                         운영기관명       도서관전화번호  \
# 0        22:00     16:00  ...  경상남도 거제시 덕산아내프리미엄1차아파트입주자대표회  055-681-9766
# 1        18:00     00:00  ...                      경기도 양평군청  031-771-4302
# 2        18:00     00:00  ...                      경기도 양평군청  031-775-7483
# 3        22:00     08:00  ...                      경기도 양평군청  031-770-2571
# 4        22:00     08:00  ...                      경기도 양평군청  031-770-2561
# ...        ...       ...  ...                           ...           ...
# 3313     17:00     13:00  ...                     경상남도 하동군청  032-123-4567
# 3314     18:00     09:00  ...                      경상남도 밀양시  055-359-6045
# 3315     23:00     08:00  ...                      경상남도 밀양시  055-359-6026
# 3316     23:00     08:00  ...                          나주시청  061-339-4581
# 3317     23:00     08:00  ...                          나주시청  061-339-2551
#
#          부지면적     건물면적                      홈페이지주소         위도          경도  \
# 0     31675.0   142.00                         NaN  34.866433  128.684936
# 1       634.0   179.00      http://www.yplib.go.kr  37.496177  127.411217
# 2      3927.0   140.00      http://www.yplib.go.kr  37.480695  127.478067
# 3      3434.0  1314.00      http://www.yplib.go.kr  37.419191  127.754688
# 4      2215.0  1045.00      http://www.yplib.go.kr  37.473719  127.638517
# ...       ...      ...                         ...        ...         ...
# 3313    330.0   475.20  http://hadong.libekas4.net  34.123457  123.123457
# 3314   5047.0  1104.00     http://eng.myclib.or.kr  35.486850  128.752564
# 3315   5629.0  5907.00     http://www.myclib.or.kr  35.486850  128.752564
# 3316   2188.0  1215.00           www.najulib.go.kr  34.998874  126.709512
# 3317   8999.1  1452.84           www.najulib.go.kr  35.021978  126.790402
#
#          데이터기준일자   제공기관코드     제공기관명
# 0     2020-01-30  5370000  경상남도 거제시
# 1     2020-03-06  4170000   경기도 양평군
# 2     2020-03-06  4170000   경기도 양평군
# 3     2020-03-06  4170000   경기도 양평군
# 4     2020-03-06  4170000   경기도 양평군
# ...          ...      ...       ...
# 3313  2017-07-26  5440000  경상남도 하동군
# 3314  2017-03-31  5360000  경상남도 밀양시
# 3315  2017-03-31  5360000  경상남도 밀양시
# 3316  2017-04-03  4830000  전라남도 나주시
# 3317  2017-04-03  4830000  전라남도 나주시
#
# [3318 rows x 28 columns]

# %%
# sports

# %%
office
# Out:
#                      개방시설명        개방장소명 개방시설유형구분  \
# 0         아르코공연연습센터 광주세미나실      소촌아트팩토리      강의실
# 1          아르코공연연습센터 광주리딩룸      소촌아트팩토리      강의실
# 2            송광종합사회복지관 소강당    송광종합사회복지관       강당
# 3           송광종합사회복지관 한사랑방    송광종합사회복지관      강의실
# 4     송정1동 행정복지센터 다목적실(2층)  송정1동 행정복지센터     다목적실
# ...                    ...          ...      ...
# 6717                 여수문화홀        여수문화홀       강당
# 6718                해오름전시실       해오름전시실      전시실
# 6719                상주문화회관       상주문화회관       기타
# 6720                청소년수련관       청소년수련관    풋살경기장
# 6721                 평생학습관        평생학습관       강당
#
#                                휴관일 평일운영시작시각 평일운영종료시각 주말운영시작시각 주말운영종료시각 유료사용여부  \
# 0                                월    10:00    18:00    10:00    18:00      N
# 1                                월    10:00    18:00    10:00    18:00      N
# 2                               주말    09:00    18:00    00:00    00:00      Y
# 3                               주말    09:00    18:00    00:00    00:00      Y
# 4                               주말    09:00    17:00    00:00    00:00      N
# ...                            ...      ...      ...      ...      ...    ...
# 6717                행사없는 토,일요일,공휴일    08:00    22:00    08:00    22:00      Y
# 6718                           월요일    09:00    18:00    09:00    18:00      N
# 6719                            명절    09:00    22:00    09:00    22:00      Y
# 6720                 명절(신정,구정, 추석)    09:00    21:00    09:00    18:00      Y
# 6721  상하반기 평생교육, 평생대학 운영기간(3월~11월)    09:00    18:00    09:00    18:00      Y
#
#      사용기준시간  ...               소재지지번주소      관리기관명        담당부서명      사용안내전화번호  \
# 0       NaN  ...     광주광역시 광산구 소촌동 845       광산구청        문화예술과  062-960-3688
# 1       NaN  ...     광주광역시 광산구 소촌동 845       광산구청        문화예술과  062-960-3688
# 2         1  ...  광주광역시 광산구 우산동 1603-1       광산구청       공동체복지과  062-941-8248
# 3         1  ...  광주광역시 광산구 우산동 1603-1       광산구청       공동체복지과  062-941-8248
# 4       NaN  ...   광주광역시 광산구 송정동 756-1       광산구청  송정1동 행정복지센터  062-960-7942
# ...     ...  ...                   ...        ...          ...           ...
# 6717      4  ...                   NaN  전라남도 여수시청        문화예술과  061-659-4692
# 6718      0  ...                   NaN  전라남도 여수시청        문화예술과  061-666-3766
# 6719     13  ...                   NaN  경상북도 상주시청        문화예술과  054-537-6215
# 6720      1  ...                   NaN  경상북도 상주시청        평생학습원  054-537-5562
# 6721      2  ...                   NaN  경상북도 상주시청     상주시평생학습원  054-537-6048
#
#                                          홈페이지주소         위도          경도  \
# 0                 https://www.arko.or.kr/infra/  35.152627  126.791234
# 1                 https://www.arko.or.kr/infra/  35.152627  126.791234
# 2                            www.gwangsan.go.kr  35.159824  126.804145
# 3                            www.gwangsan.go.kr  35.159824  126.804145
# 4                            www.gwangsan.go.kr  35.140746  126.798783
# ...                                         ...        ...         ...
# 6717                                        NaN  34.760520  127.662136
# 6718                                        NaN  34.739025  127.748151
# 6719  http://www.sangju.go.kr/culture/index.jsp  36.411915  128.159163
# 6720                  http://youth.sangju.go.kr  36.429813  128.162789
# 6721        http://sangju.go.kr/women/index.jsp  36.415279  128.169123
#
#          데이터기준일자   제공기관코드      제공기관명
# 0     2020-07-20  3630000  광주광역시 광산구
# 1     2020-07-20  3630000  광주광역시 광산구
# 2     2020-07-20  3630000  광주광역시 광산구
# 3     2020-07-20  3630000  광주광역시 광산구
# 4     2020-07-20  3630000  광주광역시 광산구
# ...          ...      ...        ...
# 6717  2019-06-17  4810000   전라남도 여수시
# 6718  2019-06-17  4810000   전라남도 여수시
# 6719  2019-05-27  5110000   경상북도 상주시
# 6720  2019-05-27  5110000   경상북도 상주시
# 6721  2019-05-27  5110000   경상북도 상주시
#
# [6722 rows x 29 columns]

# %%
gu_loc
# Out:
#     순번  시군구코드 시군구명_한글          시군구명_영문  ESRI_PK         위도          경도
# 0    1  11320     도봉구        Dobong-gu        0  37.665861  127.031767
# 1    2  11380     은평구     Eunpyeong-gu        1  37.617612  126.922700
# 2    3  11230    동대문구    Dongdaemun-gu        2  37.583801  127.050700
# 3    4  11590     동작구       Dongjak-gu        3  37.496504  126.944307
# 4    5  11545     금천구     Geumcheon-gu        4  37.460097  126.900155
# 5    6  11530     구로구          Guro-gu        5  37.495486  126.858121
# 6    7  11110     종로구        Jongno-gu        6  37.599100  126.986149
# 7    8  11305     강북구       Gangbuk-gu        7  37.646995  127.014716
# 8    9  11260     중랑구      Jungnang-gu        8  37.595379  127.093967
# 9   10  11680     강남구       Gangnam-gu        9  37.495985  127.066409
# 10  11  11500     강서구       Gangseo-gu       10  37.565762  126.822656
# 11  12  11140      중구          Jung-gu       11  37.557945  126.994190
# 12  13  11740     강동구      Gangdong-gu       12  37.549208  127.146482
# 13  14  11215     광진구      Gwangjin-gu       13  37.548144  127.085753
# 14  15  11440     마포구          Mapo-gu       14  37.562291  126.908780
# 15  16  11650     서초구        Seocho-gu       16  37.476953  127.037810
# 16  17  11290     성북구      Seongbuk-gu       17  37.606991  127.023218
# 17  18  11350     노원구         Nowon-gu       18  37.655264  127.077120
# 18  19  11710     송파구        Songpa-gu       19  37.504853  127.114482
# 19  20  11410    서대문구     Seodaemun-gu       21  37.582037  126.935667
# 20  21  11470     양천구     Yangcheon-gu       22  37.527062  126.856153
# 21  22  11560    영등포구  Yeongdeungpo-gu       23  37.520641  126.913924
# 22  23  11620     관악구        Gwanak-gu       15  37.465399  126.943807
# 23  24  11200     성동구     Seongdong-gu       20  37.550675  127.040962
# 24  25  11170     용산구       Yongsan-gu       24  37.531101  126.981074

# %%
dong
# Out:
#             행정동코드      시도명  시군구명   읍면동명       법정동코드    동리명      생성일자  말소일자
# 0      1100000000    서울특별시   NaN    NaN  1100000000  서울특별시  19880423   NaN
# 1      1111000000    서울특별시   종로구    NaN  1111000000    종로구  19880423   NaN
# 2      1111051500    서울특별시   종로구  청운효자동  1111010100    청운동  20081101   NaN
# 3      1111051500    서울특별시   종로구  청운효자동  1111010200    신교동  20081101   NaN
# 4      1111051500    서울특별시   종로구  청운효자동  1111010300    궁정동  20081101   NaN
# ...           ...      ...   ...    ...         ...    ...       ...   ...
# 21717  5013061000  제주특별자치도  서귀포시    중문동  5013011400    대포동  20060701   NaN
# 21718  5013061000  제주특별자치도  서귀포시    중문동  5013011800    하원동  20060701   NaN
# 21719  5013062000  제주특별자치도  서귀포시    예래동  5013011900    색달동  20060701   NaN
# 21720  5013062000  제주특별자치도  서귀포시    예래동  5013012000    상예동  20060701   NaN
# 21721  5013062000  제주특별자치도  서귀포시    예래동  5013012100    하예동  20060701   NaN
#
# [21722 rows x 8 columns]

# %% [markdown]
# # 각 데이터 컬럼 보기

# %%
bus.columns
# Out:
# Index(['표준ID', 'ARS-ID', '정류장명', 'X좌표', 'Y좌표', '비고'], dtype='object')

# %%
park.columns
# Out:
# Index(['공원번호', '공원명', '공원개요', '면적', '개원일', '주요시설', '주요식물', '안내도', '오시는길',
#        '이용시참고사항', '이미지', '지역', '공원주소', '관리부서', '전화번호', 'X좌표(GRS80TM)',
#        'Y좌표(GRS80TM)', 'X좌표(WGS84)', 'Y좌표(WGS84)', '바로가기'],
#       dtype='object')

# %%
museum.columns
# Out:
# Index(['시설명', '박물관미술관구분', '소재지도로명주소', '소재지지번주소', '위도', '경도', '운영기관전화번호',
#        '운영기관명', '운영홈페이지', '편의시설정보', '평일관람시작시각', '평일관람종료시각', '공휴일관람시작시각',
#        '공휴일관람종료시각', '휴관정보', '어른관람료', '청소년관람료', '어린이관람료', '관람료기타정보', '박물관미술관소개',
#        '교통안내정보', '관리기관전화번호', '관리기관명', '데이터기준일자'],
#       dtype='object')

# %%
lib.columns
# Out:
# Index(['도서관명', '시도명', '시군구명', '도서관유형', '휴관일', '평일운영시작시각', '평일운영종료시각',
#        '토요일운영시작시각', '토요일운영종료시각', '공휴일운영시작시각', '공휴일운영종료시각', '열람좌석수', '자료수(도서)',
#        '자료수(연속간행물)', '자료수(비도서)', '대출가능권수', '대출가능일수', '소재지도로명주소', '운영기관명',
#        '도서관전화번호', '부지면적', '건물면적', '홈페이지주소', '위도', '경도', '데이터기준일자', '제공기관코드',
#        '제공기관명'],
#       dtype='object')

# %%
office.columns
# Out:
# Index(['개방시설명', '개방장소명', '개방시설유형구분', '휴관일', '평일운영시작시각', '평일운영종료시각', '주말운영시작시각',
#        '주말운영종료시각', '유료사용여부', '사용기준시간', '사용료', '초과사용단위시간', '초과사용료', '수용가능인원수',
#        '면적', '부대시설정보', '신청방법구분', '시설사진정보', '소재지도로명주소', '소재지지번주소', '관리기관명',
#        '담당부서명', '사용안내전화번호', '홈페이지주소', '위도', '경도', '데이터기준일자', '제공기관코드',
#        '제공기관명'],
#       dtype='object')

# %%
gu_loc.columns
# Out:
# Index(['순번', '시군구코드', '시군구명_한글', '시군구명_영문', 'ESRI_PK', '위도', '경도'], dtype='object')

# %%
dong.columns
# Out:
# Index(['행정동코드', '시도명', '시군구명', '읍면동명', '법정동코드', '동리명', '생성일자', '말소일자'], dtype='object')

# %% [markdown]
# # 필요한 열만 남기는 전처리

# %% [markdown]
# 우선, 시설의 이름과 주소, 위도경도가 필요하다. 연식/넓이 등은 나중에 컬럼보고 돌아와서 추가할 것
#
# 완성되면 xx_df로 이름짓기

# %%
bus.head()
# Out:
#         표준ID  ARS-ID           정류장명         X좌표        Y좌표   비고
# 0  100000001    1001        종로2가사거리  126.987750  37.569765  NaN
# 1  100000002    1002    창경궁.서울대학교병원  126.996566  37.579183  NaN
# 2  100000003    1003      명륜3가.성대입구  126.998340  37.582671  NaN
# 3  100000004    1004       종로2가.삼일교  126.987613  37.568579  NaN
# 4  100000005    1005  혜화동로터리.여운형활동터  127.001744  37.586243  NaN

# %%
bus_df = bus[['정류장명','Y좌표','X좌표','표준ID','ARS-ID']]
bus_df.columns = ['정류장명','위도','경도','표준ID','ARS-ID']

# %%
park.head()
# Out:
#    공원번호       공원명                                               공원개요  \
# 0     1  남산도시자연공원  남산공원은 도심에 위치하여 서울시민에게 맑은 공기를 제공하는 자연휴식처이며 산책 꽃...
# 1     3    길동생태공원  길동생태공원은 생물의 서식처를 제공하고 종다양성을 증진시키며 자연생태계의 생물들을 ...
# 4  http://parks.seoul.go.kr/file/info/view.do?fId...  마포구
#
#                            공원주소              관리부서          전화번호  X좌표(GRS80TM)  \
# 0        서울특별시 중구 삼일대로 231(예장동)    서울특별시중부푸른도시사업소  02-3783-5900    198364.107
# 1  서울특별시 강동구 천호대로 1291(길동생태공원)   동부공원녹지사업소 길동생태공원   02-489-2770    213554.120
# 2            경기도 과천시 대공원광장로 102             전략기획실   02-500-7032    200994.267
# 3    서울특별시 성동구 뚝섬로 273 (성수동1가)          서울숲 관리사무소  02-460-2905     203695.432
# 4     서울특별시 마포구 하늘공원로 84(월드컵공원)             월드컵공원   02-300-5500    190658.070
#
#    Y좌표(GRS80TM)  X좌표(WGS84)  Y좌표(WGS84)  \
# 0    450395.554  126.990377   37.550140
# 1    448852.675  127.154779   37.540394
# 2    437163.981  127.019847   37.426449
# 3    449290.726  127.041798   37.543072
# 4    451598.831  126.878907   37.571805
#
#                                                 바로가기
# 0    http://parks.seoul.go.kr/template/sub/namsan.do
# 1   http://parks.seoul.go.kr/template/sub/gildong.do
# 2                      http://grandpark.seoul.go.kr/
# 3  http://parks.seoul.go.kr/template/sub/seoulfor...
# 4  http://parks.seoul.go.kr/template/sub/worldcup...

# %%
park_df = park[['공원명','Y좌표(WGS84)','X좌표(WGS84)','지역','공원주소']]
park_df.columns = ['공원명','위도','경도','지역','공원주소']

# %%
museum.head()
# Out:
#          시설명 박물관미술관구분               소재지도로명주소  소재지지번주소         위도          경도  \
# 0      둘리뮤지엄       공립    서울특별시 도봉구 시루봉로 1길 6      NaN  37.652432  127.027640
# 1  서대문자연사박물관       공립  서울특별시 서대문구 연희로 32길 51      NaN  37.576753  126.937858
# 2  서대문형무소역사관       공립      서울특별시 서대문구 통일로251      NaN  37.572442  126.959541
# 3    서울교육박물관       공립    서울특별시 종로구 북촌로 5길 48      NaN  37.581031  126.983694
# 4     서울상상나라       공립      서울특별시 광진구 능동로 216      NaN  37.549458  127.086261
#
#        운영기관전화번호        운영기관명                        운영홈페이지  편의시설정보  ...  \
# 0   02-990-2200          도봉구             doolymuseum.or.kr     NaN  ...
# 1   02-330-8899         서대문구         http://namu.sdm.go.kr     NaN  ...
# 2   02-360-8590         서대문구               www.sscmc.or.kr     NaN  ...
# 3  02-2011-5780  서울특별시특별시교육청    http://edumuseum.sen.go.kr     NaN  ...
# 4  02-6450-9500     서울특별시특별시  www.seoulchildrensmuseum.org     NaN  ...
#
#      휴관정보 어른관람료 청소년관람료 어린이관람료 관람료기타정보 박물관미술관소개 교통안내정보      관리기관전화번호  \
# 0  홈페이지참고  5000   5000   5000     NaN      NaN    NaN   02-990-2200
# 1  홈페이지참고  6000   3000   2000     NaN      NaN    NaN   02-330-8899
# 2  홈페이지참고  3000   1500   1000     NaN      NaN    NaN   02-360-8590
# 3  홈페이지참고     0      0      0     NaN      NaN    NaN  02-2011-5780
# 4  홈페이지참고  4000   4000   4000     NaN      NaN    NaN  02-6450-9500
#
#          관리기관명     데이터기준일자
# 0          도봉구  2017-12-31
# 1         서대문구  2017-12-31
# 2         서대문구  2017-12-31
# 3  서울특별시특별시교육청  2017-12-31
# 4     서울특별시특별시  2017-12-31
#
# [5 rows x 24 columns]

# %%
museum.columns
# Out:
# Index(['시설명', '박물관미술관구분', '소재지도로명주소', '소재지지번주소', '위도', '경도', '운영기관전화번호',
#        '운영기관명', '운영홈페이지', '편의시설정보', '평일관람시작시각', '평일관람종료시각', '공휴일관람시작시각',
#        '공휴일관람종료시각', '휴관정보', '어른관람료', '청소년관람료', '어린이관람료', '관람료기타정보', '박물관미술관소개',
#        '교통안내정보', '관리기관전화번호', '관리기관명', '데이터기준일자'],
#       dtype='object')

# %%
museum_df = museum[['시설명','위도','경도','소재지도로명주소','운영기관명','관리기관명']]

# %%
lib.head()
# Out:
#                 도서관명   시도명 시군구명  도서관유형         휴관일 평일운영시작시각 평일운영종료시각  \
# 0  덕산아내프리미엄아파트 작은도서관  경상남도  거제시  작은도서관  매주월요일, 공휴일    16:00    22:00
# 1            강하작은도서관   경기도  양평군  작은도서관   매주일,월/공휴일    09:00    18:00
# 2            강상작은도서관   경기도  양평군  작은도서관   매주일,월/공휴일    09:00    18:00
# 3              양동도서관   경기도  양평군  공공도서관   신정,설,추석연휴    08:00    22:00
# 4              지평도서관   경기도  양평군  공공도서관   신정,설,추석연휴    08:00    22:00
#
#   토요일운영시작시각 토요일운영종료시각 공휴일운영시작시각  ...                         운영기관명  \
# 0     16:00     22:00     16:00  ...  경상남도 거제시 덕산아내프리미엄1차아파트입주자대표회
# 1     09:00     18:00     00:00  ...                      경기도 양평군청
# 2     09:00     18:00     00:00  ...                      경기도 양평군청
# 3     08:00     22:00     08:00  ...                      경기도 양평군청
# 4     08:00     22:00     08:00  ...                      경기도 양평군청
#
#         도서관전화번호     부지면적    건물면적                  홈페이지주소         위도  \
# 0  055-681-9766  31675.0   142.0                     NaN  34.866433
# 1  031-771-4302    634.0   179.0  http://www.yplib.go.kr  37.496177
# 2  031-775-7483   3927.0   140.0  http://www.yplib.go.kr  37.480695
# 3  031-770-2571   3434.0  1314.0  http://www.yplib.go.kr  37.419191
# 4  031-770-2561   2215.0  1045.0  http://www.yplib.go.kr  37.473719
#
#            경도     데이터기준일자   제공기관코드     제공기관명
# 0  128.684936  2020-01-30  5370000  경상남도 거제시
# 1  127.411217  2020-03-06  4170000   경기도 양평군
# 2  127.478067  2020-03-06  4170000   경기도 양평군
# 3  127.754688  2020-03-06  4170000   경기도 양평군
# 4  127.638517  2020-03-06  4170000   경기도 양평군
#
# [5 rows x 28 columns]

# %%
lib.columns
# Out:
# Index(['도서관명', '시도명', '시군구명', '도서관유형', '휴관일', '평일운영시작시각', '평일운영종료시각',
#        '토요일운영시작시각', '토요일운영종료시각', '공휴일운영시작시각', '공휴일운영종료시각', '열람좌석수', '자료수(도서)',
#        '자료수(연속간행물)', '자료수(비도서)', '대출가능권수', '대출가능일수', '소재지도로명주소', '운영기관명',
#        '도서관전화번호', '부지면적', '건물면적', '홈페이지주소', '위도', '경도', '데이터기준일자', '제공기관코드',
#        '제공기관명'],
#       dtype='object')

# %%
lib = lib[lib['시도명']=='서울특별시']
lib_df = lib[['도서관명','위도','경도','시군구명','소재지도로명주소','운영기관명']]

# %%
office.head()
# Out:
#                   개방시설명        개방장소명 개방시설유형구분 휴관일 평일운영시작시각 평일운영종료시각 주말운영시작시각  \
# 0      아르코공연연습센터 광주세미나실      소촌아트팩토리      강의실   월    10:00    18:00    10:00
# 1       아르코공연연습센터 광주리딩룸      소촌아트팩토리      강의실   월    10:00    18:00    10:00
# 2         송광종합사회복지관 소강당    송광종합사회복지관       강당  주말    09:00    18:00    00:00
# 3        송광종합사회복지관 한사랑방    송광종합사회복지관      강의실  주말    09:00    18:00    00:00
# 4  송정1동 행정복지센터 다목적실(2층)  송정1동 행정복지센터     다목적실  주말    09:00    17:00    00:00
#
#   주말운영종료시각 유료사용여부 사용기준시간  ...               소재지지번주소 관리기관명        담당부서명  \
# 0    18:00      N    NaN  ...     광주광역시 광산구 소촌동 845  광산구청        문화예술과
# 1    18:00      N    NaN  ...     광주광역시 광산구 소촌동 845  광산구청        문화예술과
# 2    00:00      Y      1  ...  광주광역시 광산구 우산동 1603-1  광산구청       공동체복지과
# 3    00:00      Y      1  ...  광주광역시 광산구 우산동 1603-1  광산구청       공동체복지과
# 4    00:00      N    NaN  ...   광주광역시 광산구 송정동 756-1  광산구청  송정1동 행정복지센터
#
#        사용안내전화번호                         홈페이지주소         위도          경도  \
# 0  062-960-3688  https://www.arko.or.kr/infra/  35.152627  126.791234
# 1  062-960-3688  https://www.arko.or.kr/infra/  35.152627  126.791234
# 2  062-941-8248             www.gwangsan.go.kr  35.159824  126.804145
# 3  062-941-8248             www.gwangsan.go.kr  35.159824  126.804145
# 4  062-960-7942             www.gwangsan.go.kr  35.140746  126.798783
#
#       데이터기준일자   제공기관코드      제공기관명
# 0  2020-07-20  3630000  광주광역시 광산구
# 1  2020-07-20  3630000  광주광역시 광산구
# 2  2020-07-20  3630000  광주광역시 광산구
# 3  2020-07-20  3630000  광주광역시 광산구
# 4  2020-07-20  3630000  광주광역시 광산구
#
# [5 rows x 29 columns]

# %%
office.columns
# Out:
# Index(['개방시설명', '개방장소명', '개방시설유형구분', '휴관일', '평일운영시작시각', '평일운영종료시각', '주말운영시작시각',
#        '주말운영종료시각', '유료사용여부', '사용기준시간', '사용료', '초과사용단위시간', '초과사용료', '수용가능인원수',
#        '면적', '부대시설정보', '신청방법구분', '시설사진정보', '소재지도로명주소', '소재지지번주소', '관리기관명',
#        '담당부서명', '사용안내전화번호', '홈페이지주소', '위도', '경도', '데이터기준일자', '제공기관코드',
#        '제공기관명'],
#       dtype='object')

# %%
office = office[office['제공기관명'].str.contains('서울특별시')]
office_df = office[['개방장소명','위도','경도','소재지도로명주소','소재지지번주소','관리기관명','제공기관명']]

# %%
gu_loc.head()
# Out:
#    순번  시군구코드 시군구명_한글        시군구명_영문  ESRI_PK         위도          경도
# 0   1  11320     도봉구      Dobong-gu        0  37.665861  127.031767
# 1   2  11380     은평구   Eunpyeong-gu        1  37.617612  126.922700
# 2   3  11230    동대문구  Dongdaemun-gu        2  37.583801  127.050700
# 3   4  11590     동작구     Dongjak-gu        3  37.496504  126.944307
# 4   5  11545     금천구   Geumcheon-gu        4  37.460097  126.900155

# %%
gu_loc_df = gu_loc[['시군구명_한글','위도','경도']]

# %%
dong.head()
# Out:
#         행정동코드    시도명 시군구명   읍면동명       법정동코드    동리명      생성일자  말소일자
# 0  1100000000  서울특별시  NaN    NaN  1100000000  서울특별시  19880423   NaN
# 1  1111000000  서울특별시  종로구    NaN  1111000000    종로구  19880423   NaN
# 2  1111051500  서울특별시  종로구  청운효자동  1111010100    청운동  20081101   NaN
# 3  1111051500  서울특별시  종로구  청운효자동  1111010200    신교동  20081101   NaN
# 4  1111051500  서울특별시  종로구  청운효자동  1111010300    궁정동  20081101   NaN

# %%
dong = dong[dong['시도명']=='서울특별시']
dong_df = dong[['시군구명','읍면동명','동리명','행정동코드','법정동코드']]

# %% [markdown]
# # df들만 모아보기

# %%
bus_df
# Out:
#                 정류장명         위도          경도       표준ID  ARS-ID
# 0            종로2가사거리  37.569765  126.987750  100000001    1001
# 1        창경궁.서울대학교병원  37.579183  126.996566  100000002    1002
# 2          명륜3가.성대입구  37.582671  126.998340  100000003    1003
# 3           종로2가.삼일교  37.568579  126.987613  100000004    1004
# 4      혜화동로터리.여운형활동터  37.586243  127.001744  100000005    1005
# ...              ...        ...         ...        ...     ...
# 11275          우성아파트  37.550386  127.139339  124000334   25995
# 11276          우성아파트  37.550643  127.140046  124000333   25996
# 11277           조일약국  37.533630  127.123596  124000332   25997
# 11278           성내시장  37.536155  127.125497  124000331   25998
# 11279    천호우체국.로데오거리  37.540343  127.127337  124000330   25999
#
# [11280 rows x 5 columns]

# %%
park_df
# Out:
#                  공원명         위도          경도   지역  \
# 0           남산도시자연공원  37.550140  126.990377   중구
# 1             길동생태공원  37.540394  127.154779  강동구
# 2              서울대공원  37.426449  127.019847  과천시
# 3                서울숲  37.543072  127.041798  성동구
# 4              월드컵공원  37.571805  126.878907  마포구
# ..               ...        ...         ...  ...
# 127  용마도시자연공원(사가정공원)  37.579762  127.095997  중랑구
# 128           문화비축기지  37.571718  126.893245  마포구
# 129            경춘선숲길  37.627077  127.076482  NaN
# 130             율현공원  37.472332  127.115594  강남구
# 131          서울로7017        NaN         NaN   중구
#
#                               공원주소
# 0           서울특별시 중구 삼일대로 231(예장동)
# 1     서울특별시 강동구 천호대로 1291(길동생태공원)
# 2               경기도 과천시 대공원광장로 102
# 3       서울특별시 성동구 뚝섬로 273 (성수동1가)
# 4        서울특별시 마포구 하늘공원로 84(월드컵공원)
# ..                             ...
# 127            서울특별시 중랑구 면목7동 산50
# 128               서울특별시 마포구 증산로 87
# 129                노원구 공릉2동 산 82-2
# 130  서울특별시 강남구 율현동 밤고개로24길(율현동 56)
# 131                        서울로7017
#
# [132 rows x 5 columns]

# %%
museum_df
# Out:
#            시설명         위도          경도                         소재지도로명주소  \
# 0        둘리뮤지엄  37.652432  127.027640              서울특별시 도봉구 시루봉로 1길 6
# 1    서대문자연사박물관  37.576753  126.937858            서울특별시 서대문구 연희로 32길 51
# 2    서대문형무소역사관  37.572442  126.959541                서울특별시 서대문구 통일로251
# 3      서울교육박물관  37.581031  126.983694              서울특별시 종로구 북촌로 5길 48
# 4       서울상상나라  37.549458  127.086261                서울특별시 광진구 능동로 216
# ..         ...        ...         ...                              ...
# 154     포스코미술관  37.505831  127.056088       서울특별시 강남구 대치4동 892 포스코센터 내
# 155     학아재미술관        NaN         NaN                서울특별시 종로구 돈화문로 98
# 156    한미사진미술관  37.516608  127.113970  서울특별시 송파구 위례성대로 14 한미타워 19, 20층
# 157    헬로우뮤지움   37.507358  127.040312                 서울특별시 성동구 금호로 72
# 158     환기미술관   37.594431  126.966289            서울특별시 종로구 자하문로 40길 63
#
#            운영기관명        관리기관명
# 0            도봉구          도봉구
# 1           서대문구         서대문구
# 2           서대문구         서대문구
# 3    서울특별시특별시교육청  서울특별시특별시교육청
# 4       서울특별시특별시     서울특별시특별시
# ..           ...          ...
# 154         ㈜포스코         ㈜포스코
# 155          김로이          김로이
# 156       가현문화재단       가현문화재단
# 157   김효정\n(김이삭)   김효정\n(김이삭)
# 158     (재)환기재단      (재)환기재단
#
# [159 rows x 6 columns]

# %%
lib_df
# Out:
#                        도서관명         위도          경도       시군구명  \
# 103                대방어린이도서관  37.503024  126.925222        동작구
# 105                동작어린이도서관  37.509204  126.943434        동작구
# 106               동작상도국주도서관  37.506822  126.950996        동작구
# 202                넓은들작은도서관  37.511385  126.841418        양천구
# 203             고맙습니다 작은도서관  37.515237  126.854773        양천구
# ...                     ...        ...         ...        ...
# 3299  서울특별시교육청도봉도서관(디지털자료실)  37.652746  127.012966  서울특별시 도봉구
# 3300       도봉문화정보도서관(종합자료실)  37.644581  127.043883  서울특별시 도봉구
# 3301      도봉문화정보도서관(어린이열람실)  37.644581  127.043883  서울특별시 도봉구
# 3302     도봉어린이문화정보도서관(영 유아)  37.659007  127.049470  서울특별시 도봉구
# 3303             도봉 기적의 도서관  37.680772  127.050244  서울특별시 도봉구
#
#                         소재지도로명주소       운영기관명
# 103            서울특별시 동작구 대방동길 55  서울특별시 동작구청
# 105        서울특별시 동작구 장승배기로16길 98  서울특별시 동작구청
# 106             서울특별시 동작구 매봉로 37  서울특별시 동작구청
# 202     서울특별시 양천구 목동중앙남로 16나길 55  서울특별시 양천구청
# 203            서울특별시 양천구 중앙로 209  서울특별시 양천구청
# ...                          ...         ...
# 3299  서울특별시 도봉구 도봉구 삼양로 556(쌍문동)         NaN
# 3300  서울특별시 도봉구 도봉구 덕릉로 315 (창동)         NaN
# 3301  서울특별시 도봉구 도봉구 덕릉로 315 (창동)         NaN
# 3302    서울특별시 도봉구 도봉구 노해로69길 151         NaN
# 3303       서울특별시 도봉구 도봉구 마들로 797         NaN
#
# [523 rows x 6 columns]

# %%
office_df
# Out:
# ..   ...    ...    ...         ...         ...
# 763  강동구  성내제2동    성내동  1174065000  1174010800
# 764  강동구  성내제3동    성내동  1174066000  1174010800
# 765  강동구     길동     길동  1174068500  1174010500
# 766  강동구  둔촌제1동    둔촌동  1174069000  1174010600
# 767  강동구  둔촌제2동    둔촌동  1174070000  1174010600
#
# [768 rows x 5 columns]

# %% [markdown]
# 중간정리:
#
# 데이터는 모두 위도경도 존재.
#
# bus에는 주소정보가 없어서 행정동을 re.findall로 찾아내기가 불가능함.
#
# office는 위도경도/주소정보/구정보가 있지만 '행정복지센터(동사무소)'만 뽑아내려면 전처리 필요
#
# gu_loc은 위도경도가 있지만 '구'단위라서 크게 도움될지는...
#
# dong은 '읍면동'명과 '동리'명의 차이가 있을 듯 한데... 이걸 새주소로 어떻게 바꿔야할지도 고민해야함
#
# 즉, 동별 시설을 매칭(라벨링)하려면 3가지 방법중에 하나를 사용해야한다.
#
# 1. 주소를 전처리해서 xx동을 뽑아내고, 새로운 열로 라벨링 해주기-도로명주소는 더 어려움
#
# 2. 동사무소의 위도경도를 구해서 각각의 데이터들을 가장 가까운 동사무소로 매칭시키고 라벨링 해주기(haversine 활용)-동사무소 위도경도의 무결성 보장불가(빠진 동사무소 존재가능)
#
# 3. 2번 방법을 활용해 각각의 데이터들을 구별로 매칭 후, 인구비율등에 따라 분배하고 라벨링 해주기
# -정확도 떨어짐
#
# 1번을 활용하려면 bus를 제외하고 주소정보를 전처리 해야한다.
#
# 2번을 활용하려면 office를 전처리 해야한다.
#
# 3번을 활용하려면 인구비율이 필요하다.

# %% [markdown]
# ### 1번을 위한 주소정보 전처리

# %% [markdown]
# ### 공원

# %%
park_df
# Out:
#                  공원명         위도          경도   지역  \
# 0           남산도시자연공원  37.550140  126.990377   중구
# 1             길동생태공원  37.540394  127.154779  강동구
# 2              서울대공원  37.426449  127.019847  과천시
# 3                서울숲  37.543072  127.041798  성동구
# 4              월드컵공원  37.571805  126.878907  마포구
# ..               ...        ...         ...  ...
# 127  용마도시자연공원(사가정공원)  37.579762  127.095997  중랑구
# 128           문화비축기지  37.571718  126.893245  마포구
# 129            경춘선숲길  37.627077  127.076482  NaN
# 130             율현공원  37.472332  127.115594  강남구
# 131          서울로7017        NaN         NaN   중구
#
#                               공원주소
# 0           서울특별시 중구 삼일대로 231(예장동)
# 1     서울특별시 강동구 천호대로 1291(길동생태공원)
# 2               경기도 과천시 대공원광장로 102
# 3       서울특별시 성동구 뚝섬로 273 (성수동1가)
# 4        서울특별시 마포구 하늘공원로 84(월드컵공원)
# ..                             ...
# 127            서울특별시 중랑구 면목7동 산50
# 128               서울특별시 마포구 증산로 87
# 129                노원구 공릉2동 산 82-2
# 130  서울특별시 강남구 율현동 밤고개로24길(율현동 56)
# 131                        서울로7017
#
# [132 rows x 5 columns]

# %%
# 구 뒤에 나오는 단어를 뽑아서 데이터프레임에 라벨링 해주는 코드. 
# 함수로 발전시키면 좋겠지만, 각각의 데이터프레임이 어떤식으로 주소를 가지고 있을지 몰라 일단 작성후 복사
park_df['동'] = 0
for idx in range(len(park_df.공원주소)):
    if re.findall('구 (.+)', park_df.공원주소.loc[idx]):        

        if re.findall('(.+?) ', re.findall('구 (.+)', park_df.공원주소.loc[idx])[0]):
            park_df['동'].loc[idx] = re.findall('(.+?) ', re.findall('구 (.+)', park_df.공원주소.loc[idx])[0])[0]
            print(re.findall('(.+?) ', re.findall('구 (.+)', park_df.공원주소.loc[idx])[0])[0])
            
        else:
            park_df['동'].loc[idx] = '주의!!' + park_df.공원주소.loc[idx]            
            print('주의!!' + park_df.공원주소.loc[idx])
    else:
        park_df['동'].loc[idx] = '주의!!' + park_df.공원주소.loc[idx]
        print('주의!!' + park_df.공원주소.loc[idx])
# Out:
# 삼일대로
# 천호대로
# 주의!!경기도 과천시 대공원광장로 102
# 뚝섬로
# 하늘공원로
# 세종로
# 진관동
# 영등포동2가
# 금호동1가
# 등촌동
# 성수2가
# 명일1동
# 여의공원로
# 서울시립대로2길
# 을지로
# 신길로
# 여의대방로20길
# 능동로
# 올림픽로
# 서빙고로
# 주의!!서울특별시 서대문구 통일로251(독립공원)
# 낙산길
# 매헌로
# 관악로
# 효창원로
# 독산4동
# 북악산로
# 오류동
# 새문안로
# 사당2동
# 신정동
# 고척로45길
# 목동동로
# 허준로5길
# 성산로7길
# 가양동
# 사당동
# 방화동
# 여의대방로
# 답십리로
# 광평로10길
# 종로
# 신정동
# 마천동
# 도곡동
# 도산대로45길
# 화랑로18가길
# 창동
# 고덕2동
# 대학로8길
# 의사당대로
# 장지동
# 상일동
# 금낭화로
# 올림픽로
# 한천로43길
# 홍제동
# 염창동
# 통일로
# 오금로
# 번동
# 구산동
# 개봉동
# 삼성동
# 올림픽로
# 와룡공원길
# 묵동
# 부암동
# 은평구
# 양화진길
# 불광동
# 한글비석로12길
# 면목동
# 노량진로
# 목동
# 사직로9길
# 내발산동
# 사당동
# 북촌로
# 옥인동
# 성대로6사길
# 동남로
# 쌍문동
# 상계동
# 잠실로
# 선유로
# 손기정로
# 돈암동
# 화곡동
# 마들로
# 월계로
# 남부순환로64길
# 송림길
# 우이동
# 독산동
# 시흥대로38길
# 독산동
# 시루봉로6길
# 창동
# 용두동
# 상암동
# 창전동
# 장터1길
# 옥수동
# 문정동
# 바우뫼로12길
# 세종대로
# 대학동
# 창동
# 연동로
# 구파발동
# 원지동
# 개화동
# 광장동
# 내곡동
# 염곡동
# 우면동
# 진관동
# 신사동
# 통일로
# 수서동
# 청담동
# 둔촌동
# 통일로
# 망우동
# 숭인동
# 면목동
# 면목7동
# 증산로
# 공릉2동
# 율현동
# 주의!!서울로7017
# <ipython-input-43-37d76bd828fb>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   park_df['동'] = 0
# C:\anaconda3\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-43-37d76bd828fb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   park_df['동'].loc[idx] = re.findall('(.+?) ', re.findall('구 (.+)', park_df.공원주소.loc[idx])[0])[0]
# <ipython-input-43-37d76bd828fb>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   park_df['동'].loc[idx] = '주의!!' + park_df.공원주소.loc[idx]
# <ipython-input-43-37d76bd828fb>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 서울특별시 중랑구 면목7동 산50
# 서울특별시 마포구 증산로 87
# 노원구 공릉2동 산 82-2
# 서울특별시 강남구 율현동 밤고개로24길(율현동 56)
# 서울로7017

# %% [markdown]
# 특이한 애들
#
# 주소를 2가지 버전으로 적어둔곳이거나(서울시 oo로/서울시oo동),
#
# 여러곳에 걸쳐 있는곳이거나(서울시 oo동, oo동, oo동),
#
# 동 뒤에 별다른 정보가 없는 경우(서울시 oo구 oo동)-1개,
#
# 서울이 아닌경우(서울대공원).
#
# 더 정확히 하려면 추가 전처리 필요할듯. 특히 여러곳에 펼쳐져있는 공원의 경우...

# %% [markdown]
# ### 미술관/박물관

# %%
museum_df['동'] = 0
for idx in range(len(museum_df.소재지도로명주소)):
    if re.findall('구 (.+)', museum_df.소재지도로명주소.loc[idx]):        

        if re.findall('(.+?) ', re.findall('구 (.+)', museum_df.소재지도로명주소.loc[idx])[0]):
            museum_df['동'].loc[idx] = re.findall('(.+?) ', re.findall('구 (.+)', museum_df.소재지도로명주소.loc[idx])[0])[0]
            print(re.findall('(.+?) ', re.findall('구 (.+)', museum_df.소재지도로명주소.loc[idx])[0])[0])
            
        else:
            museum_df['동'].loc[idx] = '주의!!' + museum_df.소재지도로명주소.loc[idx]            
            print('주의!!' + museum_df.소재지도로명주소.loc[idx])
    else:
        museum_df['동'].loc[idx] = '주의!!' + museum_df.소재지도로명주소.loc[idx]
        print('주의!!' + museum_df.소재지도로명주소.loc[idx])
# Out:
# <ipython-input-46-46e1bccb0e9a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   museum_df['동'] = 0
# C:\anaconda3\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-46-46e1bccb0e9a>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   museum_df['동'].loc[idx] = re.findall('(.+?) ', re.findall('구 (.+)', museum_df.소재지도로명주소.loc[idx])[0])[0]
# <ipython-input-46-46e1bccb0e9a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   museum_df['동'].loc[idx] = '주의!!' + museum_df.소재지도로명주소.loc[idx]
# <ipython-input-46-46e1bccb0e9a>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   museum_df['동'].loc[idx] = '주의!!' + museum_df.소재지도로명주소.loc[idx]
# 시루봉로
# 연희로
# 주의!!서울특별시 서대문구 통일로251
# 북촌로
# 능동로
# 주의!!서울특별시 동대문구 약령중앙로26
# 새문안로
# 성북로
# 손기정로
# 왕십리로
# 연서로50길
# 창덕궁
# 청계천로
# 위례성대로
# 허준로
# 북촌로
# 삼성로
# 충정로
# 주의!!서울특별시 서초구 바우뫼로7길111
# 와우산로
# 화곡로
# 홍지문1길
# 동숭길
# 새문안로
# 불광로
# 도산대로
# 돈화문로
# 올림픽로
# 올림픽로
# 북촌로6길
# 인사동
# 인사동길
# 우이동
# 서소문로11길
# 임정로
# 인사동
# 북촌로11길
# 북촌로
# 주의!!서울특별시 종로구 북촌로5나길90(삼청동)
# 우정국로
# 아리수로61길
# 주의!!서울특별시 종로구 비봉길2-2
# 주의!!서울특별시 명동길 74-2
# 주의!!서울특별시 을지로 23
# 대학로
# 올림픽로
# 주의!!서울특별시 테헤란로 528(대치동 945-5)
# 북촌로
# 이화장길
# 세검정로
# 세종대로
# 63로
# 소월로
# 평창30길
# 대사관로
# 소공로
# 신촌로129
# 창의문로
# 신촌로
# 정동길
# 서초중앙로2길
# 효령로
# 월드컵북로11길
# 이태원로
# 장충단로
# 성균관로
# 퇴계로
# 돈화문로
# 주의!!서울특별시 언주로 827 코리아나아트센타
# 주의!!서울특별시 밤고개로14길 13-51
# 오류로8리길
# 주의!!서울특별시 청담동 84-9
# 대사관로
# 올림픽로35길
# 세종대로
# 율곡로10길,
# 남대문로
# 여의대방로
# 토정로
# 동호로
# 율곡로
# 혜화로
# 한남대로
# 성북로
# 주의!!서울특별시 남부순환로 152길 53
# 주의!!서울특별시 도산대로317
# 평창8길
# 능동로
# 주의!!서울특별시 동대문구 경희대로26
# 경희대로
# 경희대로
# 안암로
# 주의!!서울특별시 정릉로 77
# 삼양로
# 필동로1길
# 화랑로
# 평창문화로
# 대학로
# 관악로
# 서울특별시립대로
# 화랑로
# 성균관로
# 보문로
# 도봉로
# 도봉로
# 능동로
# 청파로
# 청파로
# 주의!!서울특별시 동작구 상도로369
# 연세로
# 이화여대길
# 이화여대길
# 주의!!서울특별시 성동구 왕십리로222
# 와우산로
# 주의!!서울특별시 화랑로 13길 60 동덕여자대학교
# 양천로4길
# 덕수궁길
# 남부순환로
# 성북로
# 옥인1길
# 공릉로
# 관악로
# 청파로
# 초안산로
# 살곶이길
# 남부순환로
# 63로
# 창경궁로35길
# 선릉로
# 우정국로
# 효창원로70길
# 삼청로
# 자하문로4길
# 일원동
# 율곡로
# 이태원로
# 평창31길
# 경희궁길
# 세종대로
# 새문안로
# 방이동
# 율곡로
# 동숭길
# 한강대로
# 율곡로3길
# 종로26
# 남부순환로
# 남부순환로
# 남부순환로
# 중앙로
# 세종대로
# 주의!!서울특별시 종로구 창의문로5가길46
# 언주로
# 평창32길
# 대치4동
# 돈화문로
# 위례성대로
# 금호로
# 자하문로

# %%
museum_df
# Out:
#            시설명         위도          경도                         소재지도로명주소  \
# 0        둘리뮤지엄  37.652432  127.027640              서울특별시 도봉구 시루봉로 1길 6
# 1    서대문자연사박물관  37.576753  126.937858            서울특별시 서대문구 연희로 32길 51
# 2    서대문형무소역사관  37.572442  126.959541                서울특별시 서대문구 통일로251
# 3      서울교육박물관  37.581031  126.983694              서울특별시 종로구 북촌로 5길 48
# 4       서울상상나라  37.549458  127.086261                서울특별시 광진구 능동로 216
# ..         ...        ...         ...                              ...
# 154     포스코미술관  37.505831  127.056088       서울특별시 강남구 대치4동 892 포스코센터 내
# 155     학아재미술관        NaN         NaN                서울특별시 종로구 돈화문로 98
# 156    한미사진미술관  37.516608  127.113970  서울특별시 송파구 위례성대로 14 한미타워 19, 20층
# 157    헬로우뮤지움   37.507358  127.040312                 서울특별시 성동구 금호로 72
# 158     환기미술관   37.594431  126.966289            서울특별시 종로구 자하문로 40길 63
#
#            운영기관명        관리기관명                      동
# 0            도봉구          도봉구                   시루봉로
# 1           서대문구         서대문구                    연희로
# 2           서대문구         서대문구  주의!!서울특별시 서대문구 통일로251
# 3    서울특별시특별시교육청  서울특별시특별시교육청                    북촌로
# 4       서울특별시특별시     서울특별시특별시                    능동로
# ..           ...          ...                    ...
# 154         ㈜포스코         ㈜포스코                   대치4동
# 155          김로이          김로이                   돈화문로
# 156       가현문화재단       가현문화재단                  위례성대로
# 157   김효정\n(김이삭)   김효정\n(김이삭)                    금호로
# 158     (재)환기재단      (재)환기재단                    자하문로
#
# [159 rows x 7 columns]

# %% [markdown]
# 특이사항
#
# 구가 안써있거나,
#
# 바로 끝나버리는 경우(서울시 oo구 oo로)
#
# 얘네만 추가 라벨링 해주면 될듯(str.contains('주의!!')해서)

# %% [markdown]
# ### 도서관

# %%
lib_df
# Out:
#                        도서관명         위도          경도       시군구명  \
# 103                대방어린이도서관  37.503024  126.925222        동작구
# 105                동작어린이도서관  37.509204  126.943434        동작구
# 106               동작상도국주도서관  37.506822  126.950996        동작구
# 202                넓은들작은도서관  37.511385  126.841418        양천구
# 203             고맙습니다 작은도서관  37.515237  126.854773        양천구
# ...                     ...        ...         ...        ...
# 3299  서울특별시교육청도봉도서관(디지털자료실)  37.652746  127.012966  서울특별시 도봉구
# 3300       도봉문화정보도서관(종합자료실)  37.644581  127.043883  서울특별시 도봉구
# 3301      도봉문화정보도서관(어린이열람실)  37.644581  127.043883  서울특별시 도봉구
# 3302     도봉어린이문화정보도서관(영 유아)  37.659007  127.049470  서울특별시 도봉구
# 3303             도봉 기적의 도서관  37.680772  127.050244  서울특별시 도봉구
#
#                         소재지도로명주소       운영기관명
# 103            서울특별시 동작구 대방동길 55  서울특별시 동작구청
# 105        서울특별시 동작구 장승배기로16길 98  서울특별시 동작구청
# 106             서울특별시 동작구 매봉로 37  서울특별시 동작구청
# 202     서울특별시 양천구 목동중앙남로 16나길 55  서울특별시 양천구청
# 203            서울특별시 양천구 중앙로 209  서울특별시 양천구청
# ...                          ...         ...
# 3299  서울특별시 도봉구 도봉구 삼양로 556(쌍문동)         NaN
# 3300  서울특별시 도봉구 도봉구 덕릉로 315 (창동)         NaN
# 3301  서울특별시 도봉구 도봉구 덕릉로 315 (창동)         NaN
# 3302    서울특별시 도봉구 도봉구 노해로69길 151         NaN
# 3303       서울특별시 도봉구 도봉구 마들로 797         NaN
#
# [523 rows x 6 columns]

# %%
len(lib_df.소재지도로명주소)
# Out:
# 523

# %%
lib_df.소재지도로명주소.iloc[0]
# Out:
# '서울특별시 동작구 대방동길 55'

# %%
lib_df['동'] = 0
for idx in range(len(lib_df.소재지도로명주소)):
    if re.findall('구 (.+)', lib_df.소재지도로명주소.iloc[idx]):        

        if re.findall('(.+?) ', re.findall('구 (.+)', lib_df.소재지도로명주소.iloc[idx])[0]):
            lib_df['동'].iloc[idx] = re.findall('(.+?) ', re.findall('구 (.+)', lib_df.소재지도로명주소.iloc[idx])[0])[0]
            print(re.findall('(.+?) ', re.findall('구 (.+)', lib_df.소재지도로명주소.iloc[idx])[0])[0])
            
        else:
            lib_df['동'].iloc[idx] = '주의!!' + lib_df.소재지도로명주소.iloc[idx]            
            print('주의!!' + lib_df.소재지도로명주소.iloc[idx])
    else:
        lib_df['동'].iloc[idx] = '주의!!' + lib_df.소재지도로명주소.iloc[idx]
        print('주의!!' + lib_df.소재지도로명주소.iloc[idx])
# Out:
# <ipython-input-51-d081f7f14f42>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lib_df['동'] = 0
# C:\anaconda3\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-51-d081f7f14f42>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lib_df['동'].iloc[idx] = re.findall('(.+?) ', re.findall('구 (.+)', lib_df.소재지도로명주소.iloc[idx])[0])[0]
# <ipython-input-51-d081f7f14f42>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lib_df['동'].iloc[idx] = '주의!!' + lib_df.소재지도로명주소.iloc[idx]
# 대방동길
# 장승배기로16길
# 매봉로
# 목동중앙남로
# 중앙로
# 목동중앙남로
# 목동중앙남로
# 지양로17길
# 목동중앙남로
# 목동중앙남로
# 목동중앙남로
# 목동중앙남로
# 목동중앙본로
# 화곡로4길
# 화곡로4길
# 화곡로4길
# 중앙로52길
# 목동서로
# 목동중앙남로
# 오목로5길
# 목동남로
# 주의!!서울특별시 동작구 양녕로23길27
# 주의!!서울특별시 동작구 사당로20길132
# 동작대로29길
# 양녕로22바길
# 솔밭로
# 노원로34길
# 한글비석로
# 월계로
# 동일로243길
# 노원로34길
# 노원로1나길
# 마들로
# 마들로
# 마들로
# 마들로
# 석계로
# 초안산로5길
# 동일로186길
# 노원로1길
# 노원로
# 공릉로55길
# 중계로
# 한글비석로
# 노원로
# 덕릉로82길
# 동일로
# 상계로
# 덕릉로
# 한글비석로
# 노해길
# 동일로227길
# 한글비석로
# 노원로
# 동일로
# 동일로
# 덕릉로
# 마들로3길
# 화랑로
# 동일로
# 구로동로26길
# 디지털로27다길
# 구로중앙로27나길
# 경인로
# 구로동로13길
# 개봉로16길
# 고척로27바길
# 오리로
# 신도림로
# 구로중앙로40길
# 경인로19길
# 동남로
# 도신로33길
# 당산로
# 영등포로25길
# 주의!!서울특별시 영등포구 국제금융로124
# 주의!!서울특별시 영등포구 영신로200
# 주의!!서울특별시 영등포구 영등포로64길15
# 신길로61길
# 국회대로
# 여의대로
# 선유로
# 문래로20길
# 주의!!서울특별시 영등포구 도신로27
# 선유로
# 주의!!서울특별시 영등포구 대림로197
# 주의!!서울특별시 영등포구 대림로23길25
# 주의!!서울특별시 영등포구 디지털로441
# 주의!!서울특별시 영등포구 여의대방로43길10
# 대방천로
# 주의!!서울특별시 영등포구 도림로264
# 주의!!서울특별시 영등포구 신길로42길1
# 주의!!서울특별시 영등포구 신길로41라길13-8
# 주의!!서울특별시 영등포구 영등포로84길24-5
# 주의!!서울특별시영등포구 선유로47길30(4층)
# 주의!!서울특별시 영등포구 영등포로11길12
# 주의!!서울특별시 영등포구 도림로141가길16
# 자하문로36길
# 종로58가길
# 명륜길
# 삼봉로
# 북촌로
# 삼일대로30길
# 자하문로13길
# 숭인동길
# 자하문로
# 평창문화로
# 통일로14길
# 송월길
# 종로35가길
# 이화장길
# 혜화로
# 창신길
# 지봉로
# 용답중앙
# 송정
# 광나루로
# 뚝섬로
# 왕십리로
# 뚝섬로
# 독서당로
# 독서당로
# 무수막
# 행당로
# 독서당로
# 행당로
# 사근동길
# 마장로
# 무학봉길
# 마장로
# 마장로
# 뚝섬로
# 고산자로
# 용답
# 난계로
# 고산자로
# 독서당로
# 독산로
# 금하로
# 시흥대로73길
# 가산로5길
# 독산로
# 시흥대로123길
# 한내로
# 범안로
# 독산로
# 주의!!서울특별시 금천구 독산로232
# 시흥대로58길
# 시흥대로18길
# 독산로36길
# 금하로21길
# 가산디지털1로
# 독산동
# 범안로12가길
# 주의!!서울특별시 금천구 벚꽃로40
# 시흥대로90길
# 독산로74길
# 시흥대로
# 시흥대로75길
# 금하로11길
# 탑골로
# 금하로23길
# 독산로64길
# 벚꽃로56길
# 밤고개로
# 남부순환로391길
# 언주로
# 압구정로
# 압구정로
# 남부순환로
# 개포로
# 광평로
# 광평로
# 양재대로55길
# 도곡로18길
# 학동로43길
# 학동로67길
# 압구정로79길
# 삼성로
# 증산서길
# 도곡로77길
# 영동대로65길
# 테헤란로8길
# 역삼로7길
# 학동로
# 일원로115(삼성생명빌딩B동
# 봉은사로
# 자곡로
# 자곡로
# 신내로15길
# 면목로
# 망우로73길
# 중랑역로3길
# 송림길
# 동일로114길
# 화랑로
# 통일로
# 아리랑로
# 성북로4길
# 종암로
# 서경로
# 한천로66길
# 종암로
# 정릉로
# 보국문로
# 아리랑로
# 보문로
# 화랑로
# 장위로21다길
# 숭인로
# 충민로
# 올림픽로
# 거마로2길
# 올림픽로
# 석촌호수로
# 성내천로
# 송이로
# 탄천동로
# 오금로
# 백제고분로37길
# 위례광장로
# 통일로78가길
# 증산로5길
# 가좌로
# 진관4로
# 진관2로
# 연서로
# 증산로17길
# 통일로
# 은평로
# 은평로
# 서오릉로4길
# 진흥로
# 서울시
# 불광로2길
# 통일로68길
# 통일로92길
# 연서로41길
# 연서로43길
# 은평구
# 갈현로
# 통일로
# 연서로27길
# 연서로21길
# 서오릉로21길
# 연서로20길
# 역말로10가길
# 서오릉로
# 백련산로
# 응암동
# 응암로16길
# 은평로8길
# 백련산로
# 응암로20길
# 백련산로
# 불광천길
# 가좌로10길
# 서오릉로
# 연서로
# 갈현로7가길
# 은평로3길
# 진흥로
# 연서로5길
# 은평구
# 서울시
# 은평로
# 증산서길
# 증산서길
# 증산로11길
# 은평터널로
# 은평터널로
# 연서로
# 진관4로
# 진관4로
# 진관4로
# 진관4로
# 진관3로
# 진관4로
# 진관2로
# 진관2로
# 진관3로
# 진관3로
# 진관3로
# 연서로
# 연서로
# 진관2로
# 북한산로
# 진관2로
# 연서로48길
# 연서로44길
# 진관1로
# 진관3로
# 연서로46길
# 진관1로
# 은평구
# 은평구
# 은평구
# 은평구
# 은평구
# 청파로93길
# 주의!!서울특별시 용산구 녹사평대로329
# 청파로49길
# 주의!!서울특별시 용산구 신흥로3가길21-7
# 주의!!서울특별시 용산구 녹사평대로150
# 주의!!서울특별시 용산구 후암로32-6
# 주의!!서울특별시 용산구 신흥로90
# 두텁바위로1길
# 효창원로8길
# 주의!!서울특별시 용산구 효창원로161
# 주의!!서울특별시 용산구 새창로12길13
# 한강대로38길
# 이촌로18길
# 회나무로13길
# 주의!!서울특별시 용산구 이태원로224-19
# 서빙고로
# 주의!!서울특별시 용산구 장문로95
# 주의!!서울특별시 용산구 장문로95
# 양천로67가길
# 공항대로53가길
# 등촌로
# 화곡로63길
# 초록마을로5길
# 곰달래로
# 곰달래로37길
# 강서로33가길
# 곰달래로57가길
# 화곡로
# 곰달래로25길
# 강서로52길
# 허준로
# 허준로
# 허준로
# 강서로
# 송정로
# 방화대로
# 개화동로23길
# 금낭화로24길
# 수명로1길
# 공항대로
# 방화대로48길
# 개화동로21길
# 초록마을로14길
# 양천로57길
# 가로공원로77길
# 공항대로
# 우현로
# 금낭화로24길
# 강서로45다길
# 곰달래로57가길
# 강서로5길
# 강서로62길
# 양천로
# 오현로
# 삼양로54길
# 솔샘로
# 도봉로20나길
# 삼양로
# 솔매로49길
# 삼양로19길
# 성안로
# 올림픽로
# 아리수로93길
# 고덕로20길
# 성안로31마길
# 낙성대로3길
# 관악산
# 난곡로64가길
# 신림로3길
# 관악로
# 관악로
# 봉천로
# 조원로
# 행운1길
# 신림로
# 낙성대로
# 난우10가길
# 관악로
# 신림로
# 신림로3길
# 남부순환로
# 대림로
# 남부순환로
# 남부순환로
# 남부순환로
# 관악로
# 청룡9길
# 호암로
# 관악산
# 행운1길
# 낙성대로3길
# 난곡로64가길
# 신림로
# 낙성대로
# 난우10가길
# 관악로
# 신림로
# 신림로3길
# 봉천로
# 국회단지2길
# 남부순환로246가길
# 난곡로
# 난곡로
# 남현1가길
# 신림동길
# 신림로29길
# 신원로3길
# 조원로
# 신림로
# 신림로
# 구암길
# 양녕로6다길
# 관악로40길
# 행운1길
# 쑥고개로
# 낙성대로4가길
# 난곡로
# 호암로
# 천호대로
# 독립문공원길
# 증가로10길
# 홍은중앙로
# 경기대로
# 독립문로
# 북아현로
# 증가로
# 세검정로1길
# 모래내로
# 통일로27길
# 통일로34길
# 세검정로4길
# 모래내로
# 수색로
# 응암로1길
# 불광천길
# 성산로
# 월드컵로
# 독막로165,
# 도화4길
# 월드컵로13길
# 마포대로7길
# 방울내로7길
# 신촌로26길
# 월드컵북로30길
# 월드컵북로
# 백범로
# 도화4길
# 토정로31길
# 마포대로11길
# 월드컵북로
# 천호대로
# 고무래로
# 청계산로7길
# 서초대로70길
# 나루터로
# 주의!!서울특별시 서초구 방배로40
# 주의!!서울특별시 서초구 명달로150
# 아차산로78길
# 능동로
# 뚝섬로26길
# 강변역로
# 긴고랑로12길
# 능동로
# 동일로76가길
# 긴고랑로
# 천호대로112길
# 자양로28가길
# 천호대로136길
# 광장로
# 자양로13길
# 자양로3가길
# 뚝섬로
# 아차산로24길
# 능동로17길
# 군자로
# 뚝섬로47길
# 자양번영로4길
# 아차산로46가길
# 주의!!서울특별시 광진구 구의로61(구의동)
# 자양번영로4길
# 자양로32길
# 아차산로
# 긴고랑로36길
# 워커힐로
# 주의!!서울특별시 광진구 용마산로1길91(중곡동)
# 자양로50가길
# 용마산로
# 자양로43길
# 구의로
# 동일로
# 용마산로
# 아차산로44길
# 용마산로24길
# 도봉구
# 도봉구
# 도봉구
# 도봉구
# 도봉구
# 도봉구
# 도봉구
# 도봉구
# 도봉구
# 도봉구
# 도봉구
# 도봉구
# 도봉구
# 도봉구
# 도봉구
# 도봉구
# 도봉구
# 도봉구
# 도봉구
# 도봉구
# 도봉구
# 도봉구
# 도봉구
# 도봉구
# 도봉구
# 도봉구
# 도봉구
# 도봉구
# 도봉구
# 도봉구
# 도봉구

# %%
lib_df
# Out:
#                        도서관명         위도          경도       시군구명  \
# 103                대방어린이도서관  37.503024  126.925222        동작구
# 105                동작어린이도서관  37.509204  126.943434        동작구
# 106               동작상도국주도서관  37.506822  126.950996        동작구
# 202                넓은들작은도서관  37.511385  126.841418        양천구
# 203             고맙습니다 작은도서관  37.515237  126.854773        양천구
# ...                     ...        ...         ...        ...
# 3299  서울특별시교육청도봉도서관(디지털자료실)  37.652746  127.012966  서울특별시 도봉구
# 3300       도봉문화정보도서관(종합자료실)  37.644581  127.043883  서울특별시 도봉구
# 3301      도봉문화정보도서관(어린이열람실)  37.644581  127.043883  서울특별시 도봉구
# 3302     도봉어린이문화정보도서관(영 유아)  37.659007  127.049470  서울특별시 도봉구
# 3303             도봉 기적의 도서관  37.680772  127.050244  서울특별시 도봉구
#
#                         소재지도로명주소       운영기관명         동
# 103            서울특별시 동작구 대방동길 55  서울특별시 동작구청      대방동길
# 105        서울특별시 동작구 장승배기로16길 98  서울특별시 동작구청  장승배기로16길
# 106             서울특별시 동작구 매봉로 37  서울특별시 동작구청       매봉로
# 202     서울특별시 양천구 목동중앙남로 16나길 55  서울특별시 양천구청    목동중앙남로
# 203            서울특별시 양천구 중앙로 209  서울특별시 양천구청       중앙로
# ...                          ...         ...       ...
# 3299  서울특별시 도봉구 도봉구 삼양로 556(쌍문동)         NaN       도봉구
# 3300  서울특별시 도봉구 도봉구 덕릉로 315 (창동)         NaN       도봉구
# 3301  서울특별시 도봉구 도봉구 덕릉로 315 (창동)         NaN       도봉구
# 3302    서울특별시 도봉구 도봉구 노해로69길 151         NaN       도봉구
# 3303       서울특별시 도봉구 도봉구 마들로 797         NaN       도봉구
#
# [523 rows x 7 columns]

# %% [markdown]
# 중간정리:
# 일단, 주소가 있는 곳들은 구 다음에 나오는 00동이나 00로를 가지고 라벨링하게 했는데,
# 00로 로 끝나버리는 곳들은 주의에러가 뜨는 경우,
# 데이터 내에서 띄어쓰기가 잘못되어있는경우,
# 도봉구 도봉구처럼 데이터자체가 문제가 있는 경우등이 있어서
# 전처리를 더 해줘야 한다.
#
# 하지만 이 전처리가 다 된다고 해도
# 00로 만 가지고 ~동으로 매칭할 수 있을지 알아봐야 함.
#
# 요약: 확실한 전처리 더 필요, 도로명주소와 동매칭 탐구필요

# %% [markdown]
# ### 2번을 위한 office 전처리

# %%
office_df
# Out:
#           개방장소명         위도          경도                    소재지도로명주소 소재지지번주소  \
# 535    방학3동주민센터  37.659141  127.027992           서울특별시 도봉구 시루봉로 94     NaN
# 536    방학3동주민센터  37.659141  127.027992           서울특별시 도봉구 시루봉로 94     NaN
# 537     창1동주민센터  37.648529  127.044045           서울특별시 도봉구 해등로4길 3     NaN
# 538     창2동주민센터  37.641390  127.035640       서울특별시 도봉구 덕릉로59길 73-3     NaN
#        '양천구 신월3동자치회관 다목적실', '양천구 신월3동자치회관 사랑의정(情)나눔마루',
#        '양천구 신월4동자치회관 문화강의실', '양천구 신월4동자치회관 소회의실', '양천구 신월4동자치회관 어울림카페',
#        '양천구 나눔누리센터 강당', '양천구 목1동자치회관 대강당', '양천구 목1동자치회관 제1강의실',
#        '양천구 목2동자치회관 문화창작실', '충무스포츠센터', '회현체육센터', '훈련원공원종합체육관', '무학봉체육관',
#        '필동주민센터', '장충동주민센터', '광희동주민센터', '을지로동주민센터', '다산동주민센터', '약수동주민센터',
#        '청구동주민센터', '신당5동주민센터', '동화동주민센터', '황학동주민센터', '중림동주민센터', '소공동주민센터',
#        '회현동주민센터', '명동주민센터', '다목적실(2층)', '문화나눔방(지하)', '다용도방(2층)',
#        '체력단련실(지하)', '다목적강당(5층)', '탁구장(지하)', '북카페(3층)', '다목적실(지하1층)',
#        '다목적방(3층)', '레크레이션실(1층)', '지하강의실(지하1층)', '강당(2층)', '강의실(4층)',
#        '동아리방(7층)', '밴드연습실(지하2층)', '다용도방(3층)', '다목적실(3층)', '강의실(2층)',
#        '3층 다목적방', '3층 문화교실', '시네마실(지하)', '주민사랑방(2층)', '다용도실(1층)',
#        '다목적교실(2층)', '원터행복발전소다목적연습실(지하)', '복지나눔방(지하)', '수락홀문화공연장(5층)',
#        '생활체육실(3층)', '지하탁구장(지하1층)', '문화누리방(지하)', '회의실(2층)', '다목적방(지하)',
#        '다용도방(지하)', '소강당(6층)', '대강당', '대강당(1층)', '청소년다목적실(지하)',
#        '다목적방1(5층)', '다목적방2(5층)', '망우본동주민센터', '자양2동주민센터', '자양3동주민센터',
#        '자양4동주민센터', '화양동주민센터', '군자동주민센터', '중곡2동주민센터', '중곡3동주민센터',
#        '중곡4동주민센터', '능동주민센터', '구의1동주민센터', '구의2동주민센터', '구의3동주민센터',
#        '광장동주민센터', '자양1동주민센터', '중곡1동주민센터', '면목본동주민센터', '면목7동주민센터',
#        '면목5동주민센터', '면목4동주민센터', '면목3·8동주민센터', '면목2동주민센터', '서초구 방배3동주민센터',
#        '서초구 방배4동주민센터', '서초구 양재1동 주민센터', '서초구 양재2동 주민센터', '서초구 내곡열린문화센터',
#        '서초구 방배1동주민센터', '서초구 방배2동주민센터', '망우3동주민센터', '영등포동자치회관', '영등포동주민센터',
#        '영등포본동주민센터', '대림3동주민센터', '대림2동주민센터', '신길7동주민센터', '대림1동주민센터',
#        '대림1동자치회관', '문래동목화마을활력소', '문래동주민센터', '도림동자치회관', '도림동주민센터',
#        '당산2동주민센터', '당산1동주민센터', '여의동주민센터', '신길6동주민센터', '신길5동주민센터',
#        '신길3동주민센터', '신길1동주민센터', '양평2동주민센터', '양평동복지관', '양평1동주민센터',
#        '서초구 방배본동주민센터', '서초구 서초3동주민센터', '서초구 잠원동주민센터', '서초구 반포본동주민센터',
#        '서초구 반포1동 주민센터', '서초구 반포2동 주민센터', '서초구 반포3동주민센터', '서초구 반포4동주민센터',
#        '서초구 서초1동 주민센터', '서초구 서초2동주민센터', '신내2동주민센터', '신내1동주민센터',
#        '길음2동자치회관 2층 소회의실', '길음2동자치회관 2층 대강당', '길음2동 북카페',
#        '돈암1동자치회관 2층 강당', '돈암1동자치회관 3층 강의실', '돈암2동자치회관 2층 다목적실',
#        '돈암2동자치회관 회의실', '동선동자치회관 지하 다목적실', '동선동자치회관 2층 회의실',
#        '동선동자치회관 3층 대강당', '성북구 벤처창업지원센터 멀티미디어실', '보문동자치회관 4층 강당',
#        '보문동자치회관 3층 강의실', '삼선동자치회관 2층 회의실', '삼선동자치회관 3층 다목적실',
#        '석관동자치회관 4층 대강당', '석관동자치회관 2층 다목적회의실', '성북구청 다목적홀(B1층)',
#        '성북구청 성북아트홀', '손기정체육센터', '잠실6동주민센터', '잠실7동주민센터', '장지동주민센터',
#        '풍납1동주민센터', '풍납2동주민센터', '오금동주민센터', '방이1동주민센터(3층)',
#        '방이1동주민센터(2층 행복누리방)', '방이1동주민센터(2층 문화사랑방)', '방이2동주민센터', '삼전동주민센터',
#        '석촌동주민센터', '송파2동주민센터', '잠실2동주민센터', '잠실4동주민센터', '2층 회의실', '4층 강당',
#        '별관 6층 대강당', '3층 대강당', '3층 컴퓨터교실', '4층다목적실', '4층소강당', '5층대강당',
#        '3층 자치회관', '4층 대강당', '지하2층 탁구장', '4층 소강당', '2층 슬기실', '지하1층 다목적실',
#        '2층 북카페', '지하1층 컴퓨터실', '2층소회의실', '3층다목적실', '2층문화교실', '2층 컴퓨터실',
#        '3층 다목적실', '제천회관 1층강당', '2층소강당', '6층회의실', '청소년휴카페', '3층 회의실',
#        '4층 체육실', '5층 강당', '탁구장', '3층대강당', '지하 소회의실', '2층강당', '4층문화교실',
#        '장충문화체육센터', '남산타운문화체육센터', '중구구민회관', '중구청소년수련관',
#        '강동구 성내1동 제2강의실(3층)', '강동구 성내2동 자치회관 다목적실(3층)',
#        '강동구 성내2동 자치회관 새별실(지하1층)', '강동구 성내2동 자치회관 새미실(지하1층)',
#        '강동구 성내3동 자치회관 제1강의실(2층)', '강동구 성내3동 자치회관 다목적실(지하1층)',
#        '강동구 성내3동 자치회관 제2강의실(2층)', '강동구 길동 주민센터 회의실(3층)',
#        '강동구 둔촌2동 자치회관 다목적실(2층)', '가락본동주민센터', '거여1동주민센터', '거여2동주민센터',
#        '마천1동주민센터', '마천2동주민센터', '강동구 고덕1동 자치회관 제1강의실(3층)',
#        '강동구 고덕1동 자치회관 제2강의실(3층)', '강동구 고덕1동 자치회관 강당(4층)',
#        '강동구 고덕2동 자치회관 다목적실(2층)', '강동구 고덕2동 자치회관 소회의실(2층)',
#        '강동구 암사1동 자치회관 제2강의실(2층)', '강동구 암사1동 자치회관 주민자치위원회실(2층)',
#        '강동구 암사1동 자치회관 제1강의실(2층)', '강동구 암사1동 자치회관 다목적실(1층)',
#        '강동구 암사2동 자치회관 다목적실(3층)', '강동구 암사2동 자치회관 회의실(3층)',
#        '강동구 암사2동 자치회관 제1강의실(3층)', '강동구 암사3동 자치회관 다목적실1(4층)',
#        '강동구 암사3동 자치회관 다목적실2(4층)', '강동구 암사3동 자치회관 회의실(3층)',
#        '강동구 암사3동 자치회관 강당(5층)', '강동구 천호1동  자치회관 회의실(2층)',
#        '강동구 천호1동 자치회관 다목적실(3층)', '강동구 천호2동 주민센터 회의실(3층)',
#        '강동구 천호2동 제1자치회관 다목적실(4층)', '강동구 천호3동 자치회관 다목적실(3층)',
#        '강동구 천호3동 자치회관 사랑방(3층)', '강동구 성내1동 제1강의실(3층)',
#        '강동구 강일동 자치회관 해오름(3층)', '강동구 강일동 자치회관 다온(3층)',
#        '강동구 상일동 주민센터 3층 2강좌실', '강동구 명일1동 자치회관 강의실(3층)',
#        '강동구 명일1동 자치회관 다목적실(3층)', '강동구 명일2동 자치회관 다목적실(2층)',
#        '강동구 명일2동 자치회관 소회의실(2층)', '은평문화예술회관', '은평구민체육센터', '은평다목적체육관',
#        '은평구립축구장', '마포구청', '서대문구 홍제1동 자치회관 4층 문화2실',
#        '서대문구 홍제1동자치회관 4층 문화1실', '서대문구 홍제3동 주민센터 3층 문화사랑방',
#        '서대문구 홍제3동 주민센터 1층 홍삼카페', '서대문구 홍제3동 주민센터 2층 도담방',
#        '서대문구 남가좌2동 주민센터 4층 다목적실', '서대문구 남가좌2동 주민센터 5층 강의실',
#        '서대문구 북가좌1동 주민센터 2층 문화교실 2', '서대문구 북가좌2동 주민센터 2층 취미문화교실',
#        '서대문구 북가좌2동 주민센터 2층 다목적실', '서대문구 충현동 자치회관 지하공연연습실',
#        '서대문구 충현동 자치회관  3층 다산실', '서대문구 충현동 자치회관 4층 겸재실',
#        '서대문구 충현동 자치회관  5층 구암당', '서대문구 천연동 주민센터 다목적실',
#        '서대문구 천연동 주민센터 2층 취미문화교실', '서대문구 충현동 자치회관 3층 퇴계실',
#        '서대문구 북아현동 주민센터 취미교양실(301호)', '서대문구 북아현동 주민센터 지혜나눔방',
#        '서대문구 북아현동주민센터 문화사랑방', '서대문구 북아현동  주민센터 지하 음악교실',
#        '서대문구 신촌동 자치회관 제2강의실', '서대문구 연희동 주민센터 3층 미래창작소',
#        '서대문구 연희동 주민센터 3층 다목적실', '서대문구 연희동 주민센터 3층 연희책방',
#        '서대문구 홍은1동 주민센터 3층 강좌실', '서대문구 홍은2동 주민센터 예술교실',
#        '서대문구 홍은2동 주민센터 취미교실', '서대문구 남가좌1동 주민자치 지하2층 커뮤니티실1',
#        '서대문구 남가좌1동 주민센터 지하2층 커뮤니티실2', '서대문구 남가좌1동 주민센터 지하2층 커뮤니티실3',
#        '서대문구 남가좌1동 주민센터 3층 대강당', '서대문구 홍제3동 주민센터 2층 멀티학습실',
#        '서대문구 남가좌2동 주민센터 지하1층 강의실', '신사2동 자치회관', '증산동 자치회관', '수색동 자치회관',
#        '진관동 자치회관', '구산동 자치회관', '대조동 자치회관', '응암1동 문화의 집', '응암2동 자치회관',
#        '응암3동 자치회관', '역촌동 자치회관', '신사1동 자치회관', '녹번동 자치회관', '불광1동 자치회관',
#        '불광2동 자치회관', '갈현1동 문화의집', '갈현2동 자치회관'], dtype=object)

# %%
office_df = office_df[office_df['개방장소명'].str.contains('주민센터')]
office_df
# Out:
#                             개방장소명         위도          경도  \
# 535                      방학3동주민센터  37.659141  127.027992
# 536                      방학3동주민센터  37.659141  127.027992
# 537                       창1동주민센터  37.648529  127.044045
# 538                       창2동주민센터  37.641390  127.035640
# 550                      방학3동주민센터  37.659141  127.027992
# ...                           ...        ...         ...
# 6430  서대문구 남가좌1동 주민센터 지하2층 커뮤니티실2  37.570880  126.916498
# 6431  서대문구 남가좌1동 주민센터 지하2층 커뮤니티실3  37.570880  126.916498
# 6432       서대문구 남가좌1동 주민센터 3층 대강당  37.570880  126.916498
# 6433      서대문구 홍제3동 주민센터 2층 멀티학습실  37.593717  126.949739
# 6434     서대문구 남가좌2동 주민센터 지하1층 강의실  37.578378  126.923871
#
#                    소재지도로명주소                 소재지지번주소                  관리기관명  \
# 535       서울특별시 도봉구 시루봉로 94                     NaN             서울특별시 도봉구청
# 536       서울특별시 도봉구 시루봉로 94                     NaN             서울특별시 도봉구청
# 537       서울특별시 도봉구 해등로4길 3                     NaN             서울특별시 도봉구청
# 538   서울특별시 도봉구 덕릉로59길 73-3                     NaN             서울특별시 도봉구청
# 550       서울특별시 도봉구 시루봉로 94                     NaN             서울특별시 도봉구청
# ...                     ...                     ...                    ...
# 6430  서울특별시 서대문구 모래내로15길 37  서울특별시 서대문구 남가좌동 115-36  서울특별시 서대문구 남가좌2동 주민센터
# 6431  서울특별시 서대문구 모래내로15길 37  서울특별시 서대문구 남가좌동 115-36  서울특별시 서대문구 남가좌2동 주민센터
# 6432  서울특별시 서대문구 모래내로15길 37  서울특별시 서대문구 남가좌동 115-36  서울특별시 서대문구 남가좌3동 주민센터
# 6433   서울특별시 서대문구 세검정로4길 32     서울특별시 서대문구 홍제동 7-13   서울특별시 서대문구 홍제3동 주민센터
# 6434   서울특별시 서대문구 증가로10길 28  서울특별시 서대문구 남가좌동 115-36  서울특별시 서대문구 남가좌2동 주민센터
#
#            제공기관명
# 535    서울특별시 도봉구
# 536    서울특별시 도봉구
# 537    서울특별시 도봉구
# 538    서울특별시 도봉구
# 550    서울특별시 도봉구
# ...          ...
# 6430  서울특별시 서대문구
# 6431  서울특별시 서대문구
# 6432  서울특별시 서대문구
# 6433  서울특별시 서대문구
# 6434  서울특별시 서대문구
#
# [499 rows x 7 columns]

# %%
dong_df.groupby(['읍면동명']).count()
# Out:
#        시군구명  동리명  행정동코드  법정동코드
# 읍면동명
# 가락1동      1    1      1      1
# 가락2동      1    1      1      1
# 가락본동      1    1      1      1
# 가리봉동      1    1      1      1
# 가산동       1    1      1      1
# ...     ...  ...    ...    ...
# 효창동       1    1      1      1
# 후암동       1    1      1      1
# 휘경제1동     1    1      1      1
# 휘경제2동     1    1      1      1
# 흑석동       1    1      1      1
#
# [424 rows x 4 columns]

# %% [markdown]
# 중복포함 499개랑 중복없이 742개는 너무 에러가 크다.
#
# 2번은 데이터를 더 구해야 할 듯.

# %% [markdown]
# ### 3번을 위한 haversine코드

# %%
close_gu = {'구' : [], '공원' : []}
for idx, park in tqdm(enumerate(park_df.공원명)):
    start = (float(park_df.loc[idx]['위도']), float(park_df.loc[idx]['경도']))
    distance_dic = {}
    for idx, gu in enumerate(gu_loc_df.시군구명_한글):
        goal = (gu_loc_df.loc[idx]['위도'].mean(), gu_loc_df.loc[idx]['경도'].mean())
        distance_dic[gu] = float(haversine(start, goal))
    closest = sorted((value, key) for key, value in distance_dic.items())[0][1]
    close_gu['구'].append(closest)
    close_gu['공원'].append(park)
mapping = pd.DataFrame(close_gu)
mapping = mapping[['공원','구']]
mapping
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
#                   공원    구
# 0           남산도시자연공원   중구
# 1             길동생태공원  강동구
# 2              서울대공원  서초구
# 3                서울숲  성동구
# 4              월드컵공원  마포구
# ..               ...  ...
# 127  용마도시자연공원(사가정공원)  중랑구
# 128           문화비축기지  마포구
# 129            경춘선숲길  노원구
# 130             율현공원  송파구
# 131          서울로7017  도봉구
#
# [132 rows x 2 columns]

# %% [markdown]
# # 함수짜기

# %% [markdown]
# loc_df에는 구/행정동의 위도경도가 담겨있어야 하고
#
# data_df에는 데이터와 위도경도가,
#
# name에는 data의 이름(도서관명/지하철역명)이 지정되야 한다.
#
# '시군구명_한글'은 loc_df에 들어가는 구/행정동의 열 이름이 들어가면 된다

# %%
def mapping(loc_df, data_df, name):
    close_gu = {'구' : [], '{}'.format(name) : []}
    for idx, data in tqdm(enumerate(data_df['{}'.format(name)])):
        start = (float(data_df.iloc[idx]['위도']), float(data_df.iloc[idx]['경도']))
        distance_dic = {}
        for idx, gu in enumerate(loc_df.시군구명_한글):#loc_df가 바뀌면 같이 바꿔주어야 함
            goal = (loc_df.iloc[idx]['위도'].mean(), loc_df.iloc[idx]['경도'].mean())
            distance_dic[gu] = float(haversine(start, goal))
        closest = sorted((value, key) for key, value in distance_dic.items())[0][1]
        close_gu['구'].append(closest)
        close_gu['{}'.format(name)].append(data)
    mapping = pd.DataFrame(close_gu)
    mapping = mapping[['{}'.format(name),'구']]
    return mapping

# %%
bus_map = mapping(gu_loc_df, bus_df, '정류장명')
bus_map
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
#                 정류장명    구
# 0            종로2가사거리   중구
# 1        창경궁.서울대학교병원   중구
# 2          명륜3가.성대입구  종로구
# 3           종로2가.삼일교   중구
# 4      혜화동로터리.여운형활동터  종로구
# ...              ...  ...
# 11275          우성아파트  강동구
# 11276          우성아파트  강동구
# 11277           조일약국  강동구
# 11278           성내시장  강동구
# 11279    천호우체국.로데오거리  강동구
#
# [11280 rows x 2 columns]

# %%
bus_map.groupby(['구']).count()
# Out:
#       정류장명
# 구
# 강남구    365
# 강동구    373
# 강북구    336
# 강서구    394
# 관악구    254
# 광진구    335
# 구로구    525
# 금천구    476
# 노원구    401
# 도봉구    316
# 동대문구   353
# 동작구    652
# 마포구    559
# 서대문구   490
# 서초구    596
# 성동구    448
# 성북구    745
# 송파구    484
# 양천구    543
# 영등포구   519
# 용산구    494
# 은평구    390
# 종로구    260
# 중구     513
# 중랑구    459

# %%
park_map = mapping(gu_loc_df, park_df, '공원명')
park_map
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
#                  공원명    구
# 0           남산도시자연공원   중구
# 1             길동생태공원  강동구
# 2              서울대공원  서초구
# 3                서울숲  성동구
# 4              월드컵공원  마포구
# ..               ...  ...
# 127  용마도시자연공원(사가정공원)  중랑구
# 128           문화비축기지  마포구
# 129            경춘선숲길  노원구
# 130             율현공원  송파구
# 131          서울로7017  도봉구
#
# [132 rows x 2 columns]

# %%
park_map.groupby(['구']).count()
# Out:
#       공원명
# 구
# 강남구     5
# 강동구     7
# 강북구     3
# 강서구     6
# 관악구     2
# 광진구     2
# 구로구     5
# 금천구     4
# 노원구     4
# 도봉구     5
# 동대문구    5
# 동작구     6
# 마포구     8
# 서대문구    6
# 서초구     8
# 성동구     6
# 성북구     4
# 송파구     7
# 양천구     6
# 영등포구    5
# 용산구     2
# 은평구     6
# 종로구     4
# 중구     10
# 중랑구     6

# %%
museum_map = mapping(gu_loc_df, museum_df, '시설명')
museum_map
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
#            시설명     구
# 0        둘리뮤지엄   강북구
# 1    서대문자연사박물관  서대문구
# 2    서대문형무소역사관  서대문구
# 3      서울교육박물관   종로구
# 4       서울상상나라   광진구
# ..         ...   ...
# 154     포스코미술관   강남구
# 155     학아재미술관   도봉구
# 156    한미사진미술관   송파구
# 157    헬로우뮤지움    강남구
# 158     환기미술관    종로구
#
# [159 rows x 2 columns]

# %%
museum_map.groupby(['구']).count()
# Out:
#       시설명
# 구
# 강남구     5
# 강동구     1
# 강북구     3
# 강서구     3
# 관악구     2
# 광진구     3
# 구로구     1
# 노원구     2
# 도봉구    33
# 동대문구    6
# 동작구     1
# 마포구     5
# 서대문구    7
# 서초구     5
# 성동구     4
# 성북구     2
# 송파구     9
# 영등포구    2
# 용산구     2
# 은평구     2
# 종로구    32
# 중구     29

# %%
lib_map = mapping(gu_loc_df, lib_df, '도서관명')
lib_map
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
#                       도서관명    구
# 0                 대방어린이도서관  동작구
# 1                 동작어린이도서관  동작구
# 2                동작상도국주도서관  동작구
# 3                 넓은들작은도서관  양천구
# 4              고맙습니다 작은도서관  양천구
# ..                     ...  ...
# 518  서울특별시교육청도봉도서관(디지털자료실)  강북구
# 519       도봉문화정보도서관(종합자료실)  강북구
# 520      도봉문화정보도서관(어린이열람실)  강북구
# 521     도봉어린이문화정보도서관(영 유아)  도봉구
# 522             도봉 기적의 도서관  도봉구
#
# [523 rows x 2 columns]

# %%
lib_map.groupby(['구']).count()
# Out:
#       도서관명
# 구
# 강남구     15
# 강동구      5
# 강북구     13
# 강서구     19
# 관악구     34
# 광진구      1
# 구로구     12
# 금천구     31
# 노원구     24
# 도봉구     96
# 동대문구     3
# 동작구     22
# 마포구     14
# 서대문구    26
# 서초구     10
# 성동구     23
# 성북구     18
# 송파구     13
# 양천구     34
# 영등포구    26
# 용산구     20
# 은평구     36
# 종로구      7
# 중구      11
# 중랑구     10

# %% [markdown]
# ### 정리:
# 복지시설 데이터 중,
#
# 버스정류소/공원/박물관+미술관/도서관 데이터를 구해서 전처리 후 위도경도와 주소데이터를 구했다.
#
# 체육시설 데이터는 하은이 데이터반출 기다리고 있고,
#
# 지하철데이터는 아직 좋은 자료를 구하지 못했다.
#
#
# 행정동과 복지시설을 매칭하는 방법을 3가지 생각해서 시도했다.
#
# 1번, 2번, 3번중에
#
# 1번은 전처리 계속 하다보면 유의미한 결과가 나올 듯 하지만,
#
# '버스'를 커버하지 못한다는점과 도로명주소-행정동 매칭이 필요하다는 점이 문제다.
#
# 2번은 행정동별 더 좋은 위도경도 데이터를 구할 수 있으면 그렇게 하면 되고 안되면 다른방법 알아봐야함.
#
# 3번은 구별로 라벨링은 성공했지만 동별로 가야하니 2번과 같은 문제.
#
# 와우 소연이가 자료 지하철 구했대!

# %%
# with open('./지하철 승차데이터_규호.pkl','rb') as up:
#     train_up = pickle.load(up)

# %% [markdown]
# # tips...

# %% [markdown]
# ### 특정 문자열이 그안에 있는 행만 챙기는 법(&쓰면 다중조건가능)
# ##### df[df['asdf'].str.contains('asdf') & df['zxcv'].str.contains('zxcv')]

# %% [markdown]
# # 이것저것 전처리(볼필요X, 나중에 성공하면 위에다 반영할것임)

# %% [markdown]
# ## 공원

# %% [markdown]
# 공원번호는 전국 기준인듯하고, 면적은 몇몇개는 re써서 뽑아야할듯. 개원일은 큰 의미있을지는 모르겠다.주요시설에선 valuecount랑 unique본다음에 특수점으로 넣을지 생각하고, 지역이 대부분있는듯하지만 없으면 주소에서 뽑아야할듯.

# %%
park_need = park[['공원명','공원주소','X좌표(WGS84)','Y좌표(WGS84)', '면적']]
park_need.면적 = park_need.면적.astype(str)
park_need
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-7d71d8394ec2> in <module>
# ----> 1 park_need = park[['공원명','공원주소','X좌표(WGS84)','Y좌표(WGS84)', '면적']]
#       2 park_need.면적 = park_need.면적.astype(str)
#       3 park_need
#
# TypeError: string indices must be integers

# %%
park_need.head(40)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-77447284b4f8> in <module>
# ----> 1 park_need.head(40)
#
# NameError: name 'park_need' is not defined

# %%
for i in range(len(park_need.면적)):
#     print(re.findall('([1-9]*?\.*[1-9]+?)㎡+?m*?²*?', park_need.면적[i]))
    print(re.findall('([0-9]+?\.?[0-9]?)㎡|([0-9]+?\.?[0-9]?)m²|([0-9]+?\.?[0-9]?)㎥', park_need.면적[i]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-047c57c3035e> in <module>
# ----> 1 for i in range(len(park_need.면적)):
#       2 #     print(re.findall('([1-9]*?\.*[1-9]+?)㎡+?m*?²*?', park_need.면적[i]))
#       3     print(re.findall('([0-9]+?\.?[0-9]?)㎡|([0-9]+?\.?[0-9]?)m²|([0-9]+?\.?[0-9]?)㎥', park_need.면적[i]))
#       4
#       5
#
# NameError: name 'park_need' is not defined

# %% [markdown]
# 공원 넓이를 표현하는 방식이 다 다르다
# 그냥 1000제곱미터(㎡)라고 한곳이 있는 반면, 1000세제곱미터(㎥)로 한곳도, 1000띄어쓰기제곱미터(㎡) 한곳, 1000미터와 제곱(m²)

# %% [markdown]
# 배수지용량은 왜나오는데..;
